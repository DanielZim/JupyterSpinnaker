# %% [markdown]
# Should work with all OpenAI Roboschool environments: https://gym.openai.com/envs/#roboschool
#
# ImageStream: https://medium.com/@kostal91/displaying-real-time-webcam-stream-in-ipython-at-relatively-high-framerate-8e67428ac522

# %%
import platform
print(platform.python_version())
# Out:
# 3.7.1

# %%
from pyvirtualdisplay import Display
import gym
import roboschool
from gym import wrappers
import matplotlib.pyplot as plt
import time
# %matplotlib inline
# %matplotlib notebook

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()

env = gym.make('RoboschoolAtlasForwardWalk-v1')
env = wrappers.Monitor(env, "/tmp/RoboschoolHumanoidFlagrunHarder-v1", force=True)

for episode in range(5):
    observation = env.reset()
    step = 0
    total_reward = 0

    while True:
        step += 1
        start = time.time()
        
        env_rnd = env.render(mode='rgb_array')
        ax.clear()
        ax.imshow(env_rnd)
        fig.canvas.draw()
        
        action = env.action_space.sample()
        observation, reward, done, info = env.step(action)
        total_reward += reward   
        
        end = time.time()
        print('Time taken in milliseconds -', (end - start)*1000 )
        
        if done:
            print("Episode: {0},\tSteps: {1},\tscore: {2}".format(episode, step, total_reward))
            break
env.close()
# Out:
# <img src="data:image/png;base64,..." width="432">
# Time taken in milliseconds - 112.49566078186035
# Time taken in milliseconds - 129.61387634277344
# Time taken in milliseconds - 104.15434837341309
# Time taken in milliseconds - 103.04427146911621
# Time taken in milliseconds - 101.1817455291748
# Time taken in milliseconds - 100.17228126525879
# Time taken in milliseconds - 101.86505317687988
# Time taken in milliseconds - 100.8763313293457
# Time taken in milliseconds - 101.25923156738281
# Time taken in milliseconds - 100.77118873596191
# Time taken in milliseconds - 103.06835174560547
# Time taken in milliseconds - 100.88515281677246
# Time taken in milliseconds - 101.38988494873047
# Time taken in milliseconds - 99.15661811828613
# Time taken in milliseconds - 99.29347038269043
# Time taken in milliseconds - 100.8155345916748
# Time taken in milliseconds - 99.50542449951172
# Time taken in milliseconds - 100.44097900390625
# Time taken in milliseconds - 100.76189041137695
# ...

# %% [markdown]
# ## Plotting with Matplotlib

# %%
from pyvirtualdisplay import Display
import gym
import time
import roboschool
import IPython
from gym import wrappers

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

env = gym.make('RoboschoolHumanoidFlagrunHarder-v1')
env = wrappers.Monitor(env, "/tmp/RoboschoolHumanoidFlagrunHarder-v1", force=True)

for episode in range(5):
    observation = env.reset()
    step = 0
    total_reward = 0

    while True:
        step += 1
        start = time.time()
        
        #env_rnd = env.render(mode='rgb_array')
        
        #IPython.display.display(PIL.Image.fromarray(env_rnd))
        
        action = env.action_space.sample()
        observation, reward, done, info = env.step(action)
        total_reward += reward    
        
        end = time.time()
        print('Time taken in milliseconds -', (end - start)*1000 )
        
        if done:
            print("Episode: {0},\tSteps: {1},\tscore: {2}".format(episode, step, total_reward))
            break
env.close()
# Out:
# Time taken in milliseconds - 22.38154411315918
# Time taken in milliseconds - 17.881393432617188
# Time taken in milliseconds - 17.02594757080078
# Time taken in milliseconds - 16.671419143676758
# Time taken in milliseconds - 14.549493789672852
# Time taken in milliseconds - 13.846635818481445
# Time taken in milliseconds - 13.80014419555664
# Time taken in milliseconds - 13.642549514770508
# Time taken in milliseconds - 13.283252716064453
# Time taken in milliseconds - 13.18812370300293
# Time taken in milliseconds - 13.195037841796875
# Time taken in milliseconds - 13.164043426513672
# Time taken in milliseconds - 13.538122177124023
# Time taken in milliseconds - 13.662338256835938
# Time taken in milliseconds - 13.104915618896484
# Time taken in milliseconds - 13.288021087646484
# Time taken in milliseconds - 13.280153274536133
# Time taken in milliseconds - 13.542413711547852
# Time taken in milliseconds - 13.20195198059082
# Time taken in milliseconds - 13.041496276855469
# ...

# %% [markdown]
# ## Test without virtual display:

# %%
import gym
import roboschool

env = gym.make('RoboschoolHumanoidFlagrunHarder-v1')
env.reset()

for i in range(1000):
    #img = env.render(mode='rgb_array')
    observation, reward, done, info = env.step(env.action_space.sample()) # take a random action

env.close()
print("finished")
# Out:
# finished
