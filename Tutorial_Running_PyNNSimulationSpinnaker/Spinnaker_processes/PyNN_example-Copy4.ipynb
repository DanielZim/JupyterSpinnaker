# %%
import pyNN.spiNNaker as sim
import pyNN.utility.plotting as plot
import matplotlib.pyplot as plt
# Out:
# Detected PyNN version 0.9.4 and Neo version 0.6.1

# %% [markdown]
# ## Setting up the simulator:

# %%
sim.setup(timestep=1.0)
sim.set_number_of_neurons_per_core(sim.IF_curr_exp, 100)
# Out:
# 2019-05-17 14:43:04 INFO: Read cfg files: /home/jovyan/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/interface/spinnaker.cfg, /home/jovyan/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/spynnaker.cfg, /home/jovyan/.spynnaker.cfg
# 2019-05-17 14:43:04 INFO: Will search these locations for binaries: /home/jovyan/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/common_model_binaries : /home/jovyan/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/model_binaries
# 2019-05-17 14:43:04 INFO: Setting time scale factor to 1.0.
# 2019-05-17 14:43:04 INFO: Setting machine time step to 1000 micro-seconds.
# ['/home/jovyan/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/interface/spinnaker.cfg', '/home/jovyan/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/spynnaker.cfg', '/home/jovyan/.spynnaker.cfg']

# %% [markdown]
# ## Setting up the populations:

# %%
# Define Input neuron
# input = sim.Population(1,sim.SpikeSourceArray(spike_times=[10, 200,210,215, 217, 220, 225, 325, 456]),label="input")
#input = sim.Population(1,sim.SpikeSourceArray(spike_times=[2]),label="input")
#input = sim.Population(1, sim.SpikeSourcePoisson(rate=0), label="Input")
input = sim.Population(1, sim.SpikeSourcePoisson(), label="Input")

# Define output neuron
pop_1 = sim.Population(1,sim.IF_curr_exp(),label="pop_1")

# Connect Input Neuron with Output neuron
input_proj=sim.Projection(input,pop_1,sim.OneToOneConnector(),synapse_type=sim.StaticSynapse(weight=5,delay=1))

pop_1.record(["spikes","v"])
input.record(["spikes"])

# %% [markdown]
# ## Simulate:

# %%
simtime = 100000
sim.run(simtime)
# Out:
# 2019-05-17 14:43:04 INFO: Simulating for 100 1000ms timesteps using a hardware timestep of 1000000us
# 2019-05-17 14:43:04 INFO: Starting execution process
# 2019-05-17 14:43:09 INFO: Time 0:00:03.835072 taken by SpallocMaxMachineGenerator
# Pre allocating resources for Extra Monitor support vertices
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:19 INFO: Time 0:00:10.343738 taken by PreAllocateResourcesForExtraMonitorSupport
# Partitioning graph vertices
# |0%                          50%                         100%|
#  ============================================================
# Partitioning graph edges
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:26 INFO: Time 0:00:07.425094 taken by PartitionAndPlacePartitioner
# Created spalloc job 4642692
# 2019-05-17 14:43:26 INFO: Created spalloc job 4642692
# Waiting for board power commands to complete.
# 2019-05-17 14:43:26 INFO: Waiting for board power commands to complete.
# 2019-05-17 14:43:52 INFO: Time 0:00:25.458482 taken by SpallocAllocator
# 2019-05-17 14:43:52 INFO: Creating transceiver for 10.11.196.137
# 2019-05-17 14:43:52 INFO: Working out if machine is booted
# 2019-05-17 14:43:56 INFO: Attempting to boot machine
# 2019-05-17 14:44:02 INFO: Found board with version [Version: SC&MP 3.2.4 at SpiNNaker:0:0:0 (built Mon Mar  4 14:26:32 2019)]
# 2019-05-17 14:44:02 INFO: Machine communication successful
# 2019-05-17 14:44:02 INFO: Detected a machine on IP address 10.11.196.137 which has 816 cores and 120 links
# 2019-05-17 14:44:02 INFO: Time 0:00:09.638594 taken by MachineGenerator
# Generating partitioner report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:02 INFO: Time 0:00:00.009749 taken by PartitionerReport
# 2019-05-17 14:44:02 INFO: Time 0:00:00.000323 taken by NetworkSpecificationReport
# Allocating virtual identifiers
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:02 INFO: Time 0:00:00.026394 taken by MallocBasedChipIDAllocator
# Inserting extra monitors into graphs
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:02 INFO: Time 0:00:00.030386 taken by InsertExtraMonitorVerticesToGraphs
# Writing the board chip report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:02 INFO: Time 0:00:00.018428 taken by BoardChipReport
# Filtering edges
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:02 INFO: Time 0:00:00.029827 taken by GraphEdgeFilter
# Placing graph vertices
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:02 INFO: Time 0:00:00.035691 taken by OneToOnePlacer
# Inserting edges between vertices which require FR speed up functionality.
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:02 INFO: Time 0:00:00.061377 taken by InsertEdgesToExtraMonitorFunctionality
# generating fixed router routes.
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:02 INFO: Time 0:00:00.011698 taken by FixedRouteRouter
# Generating placement report
# |0%                          50%                         100%|
#  ============================================================
# Generating placement by core report
# |0%                          50%                         100%|
#  ============================================================
# Generating SDRAM usage report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:02 INFO: Time 0:00:00.129937 taken by PlacerReportWithApplicationGraph
# Routing
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:02 INFO: Time 0:00:00.015656 taken by RigMCRoute
# Discovering tags
# |0%                          50%                         100%|
#  ============================================================
# Allocating tags
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:02 INFO: Time 0:00:00.032485 taken by BasicTagAllocator
# Reporting Tags
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:02 INFO: Time 0:00:00.005682 taken by TagReport
# Getting number of keys required by each edge using application graph
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:02 INFO: Time 0:00:00.042204 taken by EdgeToNKeysMapper
# Getting constraints for application graph
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:02 INFO: Time 0:00:00.026731 taken by ProcessPartitionConstraints
# Allocating routing keys
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:02 INFO: Time 0:00:00.008310 taken by MallocBasedRoutingInfoAllocator
# Generating Routing info report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:02 INFO: Time 0:00:00.032233 taken by routingInfoReports
# Generating routing tables
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:02 INFO: Time 0:00:00.035955 taken by BasicRoutingTableGenerator
# Finding executable start types
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:02 INFO: Time 0:00:00.031201 taken by LocateExecutableStartType
# Initialising buffers
# |0%                          50%                         100%|
#  =========================================================2019-05-17 14:44:02 INFO: Listening for packets using tag 2 on 0.0.0.0:56300
# ===
# 2019-05-17 14:44:02 INFO: Time 0:00:00.043378 taken by BufferManagerCreator
# Generating data specifications
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:02 INFO: Time 0:00:00.066393 taken by SpynnakerDataSpecificationWriter
# Preparing Routing Tables
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:02 INFO: Time 0:00:00.012095 taken by RoutingSetup
# Finding binaries
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:02 INFO: Time 0:00:00.032345 taken by GraphBinaryGatherer
# Running routing table compression on chip
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:04 INFO: Time 0:00:01.237960 taken by MundyOnChipRouterCompression
# Generating Router table report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:04 INFO: Time 0:00:00.009091 taken by unCompressedRoutingTableReports
# loading fixed routes
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:04 INFO: Time 0:00:00.047873 taken by LoadFixedRoutes
# Clearing tags
# |0%                          50%                         100%|
#  ============================================================
# Loading Tags
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:04 INFO: Time 0:00:00.015594 taken by TagsLoader
# Writing data
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:04 INFO: Time 0:00:00.042036 taken by WriteMemoryIOData
# Executing data specifications and loading data
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:04 INFO: Time 0:00:00.156331 taken by HostExecuteDataSpecification
# Expanding Synapses
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:04 INFO: Time 0:00:00.545654 taken by SynapseExpander
# Writing fixed route report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:04 INFO: Time 0:00:00.049178 taken by FixedRouteFromMachineReport
# Loading executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:06 INFO: Time 0:00:01.440341 taken by LoadExecutableImages
# Reading Routing Tables from Machine
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:06 INFO: Time 0:00:00.015469 taken by RoutingTableFromMachineReport
# Generating compressed router table report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:06 INFO: Time 0:00:00.009058 taken by compressedRoutingTableReports
# Generating comparison of router table report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:06 INFO: Time 0:00:00.008538 taken by comparisonOfRoutingTablesReport
# 2019-05-17 14:44:06 INFO: Running for 1 steps for a total of 100000.0ms
# 2019-05-17 14:44:06 INFO: Run 1 of 1
# Updating run time
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:06 INFO: Time 0:00:00.031022 taken by ChipRuntimeUpdater
# Creating database
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:06 INFO: Time 0:00:00.045284 taken by DatabaseInterface
# 2019-05-17 14:44:06 INFO: ** Notifying external sources that the database is ready for reading **
# 2019-05-17 14:44:06 INFO: Time 0:00:00.001467 taken by NotificationProtocol
# 2019-05-17 14:44:06 INFO: *** Running simulation... ***
# Loading buffers (0 bytes)
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:44:06 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2019-05-17 14:44:06 INFO: ** Sending start / resume message to external sources to state the simulation has started or resumed. **
# 2019-05-17 14:44:06 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2019-05-17 14:44:06 INFO: Application started; waiting 100.1s for it to stop
# 2019-05-17 14:45:46 INFO: ** Sending pause / stop message to external sources to state the simulation has been paused or stopped. **
# 2019-05-17 14:45:46 INFO: Time 0:01:40.282566 taken by ApplicationRunner
# Extracting buffers from the last run
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:45:47 INFO: Time 0:00:00.294239 taken by BufferExtractor
# Getting provenance data from machine graph
# |0%                          50%                         100%|
#  ============================================================
# Getting provenance data from application graph
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:45:47 INFO: Time 0:00:00.098130 taken by GraphProvenanceGatherer
# Getting provenance data
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:45:47 INFO: Time 0:00:00.029687 taken by PlacementsProvenanceGatherer
# Getting Router Provenance
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:45:47 INFO: Time 0:00:00.069398 taken by RouterProvenanceGatherer
# Getting profile data
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:45:47 INFO: Time 0:00:00.033249 taken by ProfileDataGatherer
# 100000.0

# %% [markdown]
# ## Print:

# %%
# Input neuron
neo_input=input.get_data(variables=["spikes"])

spikes_input=neo_input.segments[0].spiketrains
print(spikes_input)
print( len(spikes_input[0]) )

# Pop1 neuron
neo_pop1=pop_1.get_data(variables=["spikes","v"])

v_pop1=neo_pop1.segments[0].filter(name='v')[0]
#print(v_pop1)

spikes_pop1=neo_pop1.segments[0].spiketrains
#print(spikes_pop1)

sim.end()
# Out:
# Getting spikes for Input
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for pop_1
# |0%                          50%                         100%|
#  ============================================================
# Getting v for pop_1
# |0%                          50%                         100%|
#  ============================================================
# [<SpikeTrain(array([ 1193.,  1205.,  1263.,  1551.,  2106.,  2273.,  2846.,  2930.,
#         4450.,  4698.,  5241.,  5769.,  5903.,  5979.,  7075., 11515.,
#        11830., 14536., 14738., 15672., 20619., 23661., 23685., 23701.,
#        24120., 25148., 25167., 26198., 26277., 29231., 29411., 31067.,
#        31662., 32204., 32624., 33642., 34449., 35786., 35900., 36523.,
#        37082., 37597., 39508., 39651., 41012., 41272., 48059., 49705.,
#        49791., 49916., 50832., 52756., 53420., 53651., 54580., 56131.,
#        56511., 56656., 56703., 59672., 62593., 62955., 63922., 65953.,
#        67408., 67538., 68318., 68394., 69248., 70120., 70209., 70353.,
#        70555., 71451., 71779., 72074., 72683., 72972., 73081., 73634.,
#        74118., 75683., 75882., 76741., 76826., 79284., 79882., 80067.,
#        81155., 83950., 85269., 92094., 92108., 93011., 93407., 94020.,
#        96440., 96747., 98146., 98287., 98862.]) * ms, [0.0 ms, 100000.0 ms])>]
# 101

# %% [markdown]
# ## Plot:

# %%
plot.Figure(
    #plot spikes for input population
    plot.Panel(spikes_input, yticks=True, markersize=5, xlim =(0, simtime)),
    
    #plot voltage for first ([0]) neuron
    plot.Panel(v_pop1, ylabel="Membrane potential (mV)", data_labels=[pop_1.label], yticks=True, xlim =(0, simtime)),
    
    #plot spikes for pop1 population
    plot.Panel(spikes_pop1, yticks=True, markersize=5, xlim =(0, simtime)),
    
    title="Simple Example",
    annotations="Simulated with {}".format(sim.name())
)
plt.show()
# Out:
# <div id='a3f65c65-3080-4ce9-a49c-cf547c440c8c'></div>
