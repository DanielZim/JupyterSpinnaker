# %%
import pyNN.spiNNaker as sim
import pyNN.utility.plotting as plot
import matplotlib.pyplot as plt
# Out:
# Detected PyNN version 0.9.4 and Neo version 0.6.1

# %% [markdown]
# ## Setting up the simulator:

# %%
sim.setup(timestep=1.0)
sim.set_number_of_neurons_per_core(sim.IF_curr_exp, 100)
# Out:
# 2019-05-17 14:37:48 INFO: Read cfg files: /home/jovyan/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/interface/spinnaker.cfg, /home/jovyan/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/spynnaker.cfg, /home/jovyan/.spynnaker.cfg
# 2019-05-17 14:37:48 INFO: Will search these locations for binaries: /home/jovyan/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/common_model_binaries : /home/jovyan/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/model_binaries
# 2019-05-17 14:37:48 INFO: Setting time scale factor to 1.0.
# 2019-05-17 14:37:48 INFO: Setting machine time step to 1000 micro-seconds.
# ['/home/jovyan/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/interface/spinnaker.cfg', '/home/jovyan/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/spynnaker.cfg', '/home/jovyan/.spynnaker.cfg']

# %% [markdown]
# ## Setting up the populations:

# %%
# Define Input neuron
# input = sim.Population(1,sim.SpikeSourceArray(spike_times=[10, 200,210,215, 217, 220, 225, 325, 456]),label="input")
#input = sim.Population(1,sim.SpikeSourceArray(spike_times=[2]),label="input")
#input = sim.Population(1, sim.SpikeSourcePoisson(rate=0), label="Input")
input = sim.Population(1, sim.SpikeSourcePoisson(), label="Input")

# Define output neuron
pop_1 = sim.Population(1,sim.IF_curr_exp(),label="pop_1")

# Connect Input Neuron with Output neuron
input_proj=sim.Projection(input,pop_1,sim.OneToOneConnector(),synapse_type=sim.StaticSynapse(weight=5,delay=1))

pop_1.record(["spikes","v"])
input.record(["spikes"])

# %% [markdown]
# ## Simulate:

# %%
simtime = 100000
sim.run(simtime)
# Out:
# 2019-05-17 14:37:48 INFO: Simulating for 10 1000ms timesteps using a hardware timestep of 1000000us
# 2019-05-17 14:37:48 INFO: Starting execution process
# 2019-05-17 14:37:53 INFO: Time 0:00:03.675240 taken by SpallocMaxMachineGenerator
# Pre allocating resources for Extra Monitor support vertices
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:04 INFO: Time 0:00:10.588670 taken by PreAllocateResourcesForExtraMonitorSupport
# Partitioning graph vertices
# |0%                          50%                         100%|
#  ============================================================
# Partitioning graph edges
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:11 INFO: Time 0:00:06.911874 taken by PartitionAndPlacePartitioner
# Created spalloc job 4642641
# 2019-05-17 14:38:11 INFO: Created spalloc job 4642641
# Waiting for board power commands to complete.
# 2019-05-17 14:38:11 INFO: Waiting for board power commands to complete.
# 2019-05-17 14:38:20 INFO: Time 0:00:09.192699 taken by SpallocAllocator
# 2019-05-17 14:38:20 INFO: Creating transceiver for 10.11.193.81
# 2019-05-17 14:38:20 INFO: Working out if machine is booted
# 2019-05-17 14:38:24 INFO: Attempting to boot machine
# 2019-05-17 14:38:29 INFO: Found board with version [Version: SC&MP 3.2.4 at SpiNNaker:0:0:0 (built Mon Mar  4 14:26:32 2019)]
# 2019-05-17 14:38:29 INFO: Machine communication successful
# 2019-05-17 14:38:29 INFO: Detected a machine on IP address 10.11.193.81 which has 816 cores and 120 links
# 2019-05-17 14:38:29 INFO: Time 0:00:09.640423 taken by MachineGenerator
# Generating partitioner report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:29 INFO: Time 0:00:00.011372 taken by PartitionerReport
# 2019-05-17 14:38:29 INFO: Time 0:00:00.000190 taken by NetworkSpecificationReport
# Allocating virtual identifiers
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:29 INFO: Time 0:00:00.040207 taken by MallocBasedChipIDAllocator
# Inserting extra monitors into graphs
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:29 INFO: Time 0:00:00.037185 taken by InsertExtraMonitorVerticesToGraphs
# Writing the board chip report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:29 INFO: Time 0:00:00.009265 taken by BoardChipReport
# Filtering edges
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:30 INFO: Time 0:00:00.036543 taken by GraphEdgeFilter
# Placing graph vertices
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:30 INFO: Time 0:00:00.040632 taken by OneToOnePlacer
# Inserting edges between vertices which require FR speed up functionality.
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:30 INFO: Time 0:00:00.055558 taken by InsertEdgesToExtraMonitorFunctionality
# generating fixed router routes.
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:30 INFO: Time 0:00:00.009894 taken by FixedRouteRouter
# Generating placement report
# |0%                          50%                         100%|
#  ============================================================
# Generating placement by core report
# |0%                          50%                         100%|
#  ============================================================
# Generating SDRAM usage report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:30 INFO: Time 0:00:00.125216 taken by PlacerReportWithApplicationGraph
# Routing
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:30 INFO: Time 0:00:00.014938 taken by RigMCRoute
# Discovering tags
# |0%                          50%                         100%|
#  ============================================================
# Allocating tags
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:30 INFO: Time 0:00:00.045033 taken by BasicTagAllocator
# Reporting Tags
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:30 INFO: Time 0:00:00.009048 taken by TagReport
# Getting number of keys required by each edge using application graph
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:30 INFO: Time 0:00:00.033932 taken by EdgeToNKeysMapper
# Getting constraints for application graph
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:30 INFO: Time 0:00:00.034087 taken by ProcessPartitionConstraints
# Allocating routing keys
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:30 INFO: Time 0:00:00.009991 taken by MallocBasedRoutingInfoAllocator
# Generating Routing info report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:30 INFO: Time 0:00:00.033944 taken by routingInfoReports
# Generating routing tables
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:30 INFO: Time 0:00:00.031529 taken by BasicRoutingTableGenerator
# Finding executable start types
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:30 INFO: Time 0:00:00.035398 taken by LocateExecutableStartType
# Initialising buffers
# |0%                          50%                         100%|
#  =========================================================2019-05-17 14:38:30 INFO: Listening for packets using tag 2 on 0.0.0.0:58404
# ===
# 2019-05-17 14:38:30 INFO: Time 0:00:00.034742 taken by BufferManagerCreator
# Generating data specifications
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:30 INFO: Time 0:00:00.060490 taken by SpynnakerDataSpecificationWriter
# Preparing Routing Tables
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:30 INFO: Time 0:00:00.010774 taken by RoutingSetup
# Finding binaries
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:30 INFO: Time 0:00:00.037995 taken by GraphBinaryGatherer
# Running routing table compression on chip
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:31 INFO: Time 0:00:01.231542 taken by MundyOnChipRouterCompression
# Generating Router table report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:31 INFO: Time 0:00:00.009084 taken by unCompressedRoutingTableReports
# loading fixed routes
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:31 INFO: Time 0:00:00.041536 taken by LoadFixedRoutes
# Clearing tags
# |0%                          50%                         100%|
#  ============================================================
# Loading Tags
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:32 INFO: Time 0:00:00.022350 taken by TagsLoader
# Writing data
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:32 INFO: Time 0:00:00.036233 taken by WriteMemoryIOData
# Executing data specifications and loading data
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:32 INFO: Time 0:00:00.155468 taken by HostExecuteDataSpecification
# Expanding Synapses
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:32 INFO: Time 0:00:00.538481 taken by SynapseExpander
# Writing fixed route report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:32 INFO: Time 0:00:00.043726 taken by FixedRouteFromMachineReport
# Loading executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:34 INFO: Time 0:00:01.440637 taken by LoadExecutableImages
# Reading Routing Tables from Machine
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:34 INFO: Time 0:00:00.014265 taken by RoutingTableFromMachineReport
# Generating compressed router table report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:34 INFO: Time 0:00:00.008517 taken by compressedRoutingTableReports
# Generating comparison of router table report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:34 INFO: Time 0:00:00.008258 taken by comparisonOfRoutingTablesReport
# 2019-05-17 14:38:34 INFO: Running for 1 steps for a total of 10000.0ms
# 2019-05-17 14:38:34 INFO: Run 1 of 1
# Updating run time
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:34 INFO: Time 0:00:00.029915 taken by ChipRuntimeUpdater
# Creating database
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:34 INFO: Time 0:00:00.045922 taken by DatabaseInterface
# 2019-05-17 14:38:34 INFO: ** Notifying external sources that the database is ready for reading **
# 2019-05-17 14:38:34 INFO: Time 0:00:00.001457 taken by NotificationProtocol
# 2019-05-17 14:38:34 INFO: *** Running simulation... ***
# Loading buffers (0 bytes)
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:34 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2019-05-17 14:38:34 INFO: ** Sending start / resume message to external sources to state the simulation has started or resumed. **
# 2019-05-17 14:38:34 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2019-05-17 14:38:34 INFO: Application started; waiting 10.1s for it to stop
# 2019-05-17 14:38:44 INFO: ** Sending pause / stop message to external sources to state the simulation has been paused or stopped. **
# 2019-05-17 14:38:44 INFO: Time 0:00:10.196877 taken by ApplicationRunner
# Extracting buffers from the last run
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:44 INFO: Time 0:00:00.122181 taken by BufferExtractor
# Getting provenance data from machine graph
# |0%                          50%                         100%|
#  ============================================================
# Getting provenance data from application graph
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:44 INFO: Time 0:00:00.112166 taken by GraphProvenanceGatherer
# Getting provenance data
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:44 INFO: Time 0:00:00.030021 taken by PlacementsProvenanceGatherer
# Getting Router Provenance
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:44 INFO: Time 0:00:00.065612 taken by RouterProvenanceGatherer
# Getting profile data
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:38:44 INFO: Time 0:00:00.028350 taken by ProfileDataGatherer
# 10000.0

# %% [markdown]
# ## Print:

# %%
# Input neuron
neo_input=input.get_data(variables=["spikes"])

spikes_input=neo_input.segments[0].spiketrains
print(spikes_input)
print( len(spikes_input[0]) )

# Pop1 neuron
neo_pop1=pop_1.get_data(variables=["spikes","v"])

v_pop1=neo_pop1.segments[0].filter(name='v')[0]
#print(v_pop1)

spikes_pop1=neo_pop1.segments[0].spiketrains
#print(spikes_pop1)

sim.end()
# Out:
# Getting spikes for Input
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for pop_1
# |0%                          50%                         100%|
#  ============================================================
# Getting v for pop_1
# |0%                          50%                         100%|
#  ============================================================
# [<SpikeTrain(array([1465., 2834., 3240., 4064., 4327., 4993., 7272., 7391., 7796.]) * ms, [0.0 ms, 10000.0 ms])>]
# 9

# %% [markdown]
# ## Plot:

# %%
plot.Figure(
    #plot spikes for input population
    plot.Panel(spikes_input, yticks=True, markersize=5, xlim =(0, simtime)),
    
    #plot voltage for first ([0]) neuron
    plot.Panel(v_pop1, ylabel="Membrane potential (mV)", data_labels=[pop_1.label], yticks=True, xlim =(0, simtime)),
    
    #plot spikes for pop1 population
    plot.Panel(spikes_pop1, yticks=True, markersize=5, xlim =(0, simtime)),
    
    title="Simple Example",
    annotations="Simulated with {}".format(sim.name())
)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">
