# %%
import pyNN.spiNNaker as sim
import pyNN.utility.plotting as plot
import matplotlib.pyplot as plt
# Out:
# Detected PyNN version 0.9.4 and Neo version 0.6.1

# %% [markdown]
# ## Setting up the simulator:

# %%
sim.setup(timestep=1.0)
sim.set_number_of_neurons_per_core(sim.IF_curr_exp, 100)
# Out:
# 2019-05-18 12:14:04 INFO: Read cfg files: /home/jovyan/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/interface/spinnaker.cfg, /home/jovyan/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/spynnaker.cfg, /home/jovyan/.spynnaker.cfg
# 2019-05-18 12:14:04 INFO: Will search these locations for binaries: /home/jovyan/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/common_model_binaries : /home/jovyan/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/model_binaries
# ['/home/jovyan/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/interface/spinnaker.cfg', '/home/jovyan/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/spynnaker.cfg', '/home/jovyan/.spynnaker.cfg']
# 2019-05-18 12:14:04 INFO: Setting time scale factor to 1.0.
# 2019-05-18 12:14:04 INFO: Setting machine time step to 1000 micro-seconds.

# %% [markdown]
# ## Setting up the populations:

# %%
# Define Input neuron
# input = sim.Population(1,sim.SpikeSourceArray(spike_times=[10, 200,210,215, 217, 220, 225, 325, 456]),label="input")
#input = sim.Population(1,sim.SpikeSourceArray(spike_times=[2]),label="input")
#input = sim.Population(1, sim.SpikeSourcePoisson(rate=0), label="Input")
input = sim.Population(1, sim.SpikeSourcePoisson(), label="Input")

# Define output neuron
pop_1 = sim.Population(1,sim.IF_curr_exp(),label="pop_1")

# Connect Input Neuron with Output neuron
input_proj=sim.Projection(input,pop_1,sim.OneToOneConnector(),synapse_type=sim.StaticSynapse(weight=5,delay=1))

pop_1.record(["spikes","v"])
input.record(["spikes"])

# %% [markdown]
# ## Simulate:

# %%
simtime = 100000
sim.run(simtime)
# Out:
# 2019-05-18 12:14:10 INFO: Simulating for 100 1000ms timesteps using a hardware timestep of 1000000us
# 2019-05-18 12:14:10 INFO: Starting execution process
# 2019-05-18 12:14:15 INFO: Time 0:00:03.609368 taken by SpallocMaxMachineGenerator
# Pre allocating resources for Extra Monitor support vertices
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:25 INFO: Time 0:00:09.808732 taken by PreAllocateResourcesForExtraMonitorSupport
# Partitioning graph vertices
# |0%                          50%                         100%|
#  ============================================================
# Partitioning graph edges
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:32 INFO: Time 0:00:06.923356 taken by PartitionAndPlacePartitioner
# Created spalloc job 4668471
# 2019-05-18 12:14:32 INFO: Created spalloc job 4668471
# Waiting for board power commands to complete.
# 2019-05-18 12:14:32 INFO: Waiting for board power commands to complete.
# 2019-05-18 12:14:37 INFO: Time 0:00:05.056542 taken by SpallocAllocator
# 2019-05-18 12:14:37 INFO: Creating transceiver for 10.11.194.65
# 2019-05-18 12:14:37 INFO: Working out if machine is booted
# 2019-05-18 12:14:41 INFO: Attempting to boot machine
# 2019-05-18 12:14:46 INFO: Found board with version [Version: SC&MP 3.2.4 at SpiNNaker:0:0:0 (built Mon Mar  4 14:26:32 2019)]
# 2019-05-18 12:14:46 INFO: Machine communication successful
# 2019-05-18 12:14:46 INFO: Detected a machine on IP address 10.11.194.65 which has 816 cores and 120 links
# 2019-05-18 12:14:46 INFO: Time 0:00:09.634974 taken by MachineGenerator
# Generating partitioner report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:46 INFO: Time 0:00:00.009746 taken by PartitionerReport
# 2019-05-18 12:14:46 INFO: Time 0:00:00.000265 taken by NetworkSpecificationReport
# Allocating virtual identifiers
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:46 INFO: Time 0:00:00.034784 taken by MallocBasedChipIDAllocator
# Inserting extra monitors into graphs
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:46 INFO: Time 0:00:00.037203 taken by InsertExtraMonitorVerticesToGraphs
# Writing the board chip report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:46 INFO: Time 0:00:00.009697 taken by BoardChipReport
# Filtering edges
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:46 INFO: Time 0:00:00.036854 taken by GraphEdgeFilter
# Placing graph vertices
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:46 INFO: Time 0:00:00.036830 taken by OneToOnePlacer
# Inserting edges between vertices which require FR speed up functionality.
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:47 INFO: Time 0:00:00.059375 taken by InsertEdgesToExtraMonitorFunctionality
# generating fixed router routes.
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:47 INFO: Time 0:00:00.009254 taken by FixedRouteRouter
# Generating placement report
# |0%                          50%                         100%|
#  ============================================================
# Generating placement by core report
# |0%                          50%                         100%|
#  ============================================================
# Generating SDRAM usage report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:47 INFO: Time 0:00:00.117294 taken by PlacerReportWithApplicationGraph
# Routing
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:47 INFO: Time 0:00:00.015431 taken by RigMCRoute
# Discovering tags
# |0%                          50%                         100%|
#  ============================================================
# Allocating tags
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:47 INFO: Time 0:00:00.044398 taken by BasicTagAllocator
# Reporting Tags
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:47 INFO: Time 0:00:00.009076 taken by TagReport
# Getting number of keys required by each edge using application graph
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:47 INFO: Time 0:00:00.026386 taken by EdgeToNKeysMapper
# Getting constraints for application graph
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:47 INFO: Time 0:00:00.039521 taken by ProcessPartitionConstraints
# Allocating routing keys
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:47 INFO: Time 0:00:00.009827 taken by MallocBasedRoutingInfoAllocator
# Generating Routing info report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:47 INFO: Time 0:00:00.031975 taken by routingInfoReports
# Generating routing tables
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:47 INFO: Time 0:00:00.030874 taken by BasicRoutingTableGenerator
# Finding executable start types
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:47 INFO: Time 0:00:00.034193 taken by LocateExecutableStartType
# Initialising buffers
# |0%                          50%                         100%|
#  =========================================================2019-05-18 12:14:47 INFO: Listening for packets using tag 2 on 0.0.0.0:44190
# ===
# 2019-05-18 12:14:47 INFO: Time 0:00:00.034628 taken by BufferManagerCreator
# Generating data specifications
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:47 INFO: Time 0:00:00.058872 taken by SpynnakerDataSpecificationWriter
# Preparing Routing Tables
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:47 INFO: Time 0:00:00.010503 taken by RoutingSetup
# Finding binaries
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:47 INFO: Time 0:00:00.037284 taken by GraphBinaryGatherer
# Running routing table compression on chip
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:48 INFO: Time 0:00:01.229262 taken by MundyOnChipRouterCompression
# Generating Router table report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:48 INFO: Time 0:00:00.008883 taken by unCompressedRoutingTableReports
# loading fixed routes
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:48 INFO: Time 0:00:00.046189 taken by LoadFixedRoutes
# Clearing tags
# |0%                          50%                         100%|
#  ============================================================
# Loading Tags
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:48 INFO: Time 0:00:00.022956 taken by TagsLoader
# Writing data
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:48 INFO: Time 0:00:00.035149 taken by WriteMemoryIOData
# Executing data specifications and loading data
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:49 INFO: Time 0:00:00.134094 taken by HostExecuteDataSpecification
# Expanding Synapses
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:49 INFO: Time 0:00:00.538905 taken by SynapseExpander
# Writing fixed route report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:49 INFO: Time 0:00:00.046161 taken by FixedRouteFromMachineReport
# Loading executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:51 INFO: Time 0:00:01.443887 taken by LoadExecutableImages
# Reading Routing Tables from Machine
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:51 INFO: Time 0:00:00.014017 taken by RoutingTableFromMachineReport
# Generating compressed router table report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:51 INFO: Time 0:00:00.008260 taken by compressedRoutingTableReports
# Generating comparison of router table report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:51 INFO: Time 0:00:00.009270 taken by comparisonOfRoutingTablesReport
# 2019-05-18 12:14:51 INFO: Running for 1 steps for a total of 100000.0ms
# 2019-05-18 12:14:51 INFO: Run 1 of 1
# Updating run time
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:51 INFO: Time 0:00:00.029878 taken by ChipRuntimeUpdater
# Creating database
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:51 INFO: Time 0:00:00.046138 taken by DatabaseInterface
# 2019-05-18 12:14:51 INFO: ** Notifying external sources that the database is ready for reading **
# 2019-05-18 12:14:51 INFO: Time 0:00:00.000739 taken by NotificationProtocol
# 2019-05-18 12:14:51 INFO: *** Running simulation... ***
# Loading buffers (0 bytes)
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:14:51 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2019-05-18 12:14:51 INFO: ** Sending start / resume message to external sources to state the simulation has started or resumed. **
# 2019-05-18 12:14:51 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2019-05-18 12:14:51 INFO: Application started; waiting 100.1s for it to stop
# 2019-05-18 12:16:31 INFO: ** Sending pause / stop message to external sources to state the simulation has been paused or stopped. **
# 2019-05-18 12:16:31 INFO: Time 0:01:40.287053 taken by ApplicationRunner
# Extracting buffers from the last run
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:16:31 INFO: Time 0:00:00.290545 taken by BufferExtractor
# Getting provenance data from machine graph
# |0%                          50%                         100%|
#  ============================================================
# Getting provenance data from application graph
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:16:31 INFO: Time 0:00:00.100746 taken by GraphProvenanceGatherer
# Getting provenance data
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:16:31 INFO: Time 0:00:00.035065 taken by PlacementsProvenanceGatherer
# Getting Router Provenance
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:16:32 INFO: Time 0:00:00.056883 taken by RouterProvenanceGatherer
# Getting profile data
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-18 12:16:32 INFO: Time 0:00:00.034090 taken by ProfileDataGatherer
# 100000.0

# %% [markdown]
# ## Print:

# %%
# Input neuron
neo_input=input.get_data(variables=["spikes"])

spikes_input=neo_input.segments[0].spiketrains
print(spikes_input)
print( len(spikes_input[0]) )

# Pop1 neuron
neo_pop1=pop_1.get_data(variables=["spikes","v"])

v_pop1=neo_pop1.segments[0].filter(name='v')[0]
#print(v_pop1)

spikes_pop1=neo_pop1.segments[0].spiketrains
#print(spikes_pop1)

sim.end()
# Out:
# Getting spikes for Input
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for pop_1
# |0%                          50%                         100%|
#  ============================================================
# Getting v for pop_1
# |0%                          50%                         100%|
#  ============================================================
# [<SpikeTrain(array([ 1236.,  2339.,  2677.,  3477.,  3682.,  4873.,  5610.,  7552.,
#         7566.,  8209.,  9263.,  9878., 10139., 14221., 14629., 15163.,
#        16020., 16084., 17478., 18824., 21078., 23653., 25146., 26074.,
#        29299., 30114., 30551., 32524., 34774., 34856., 35586., 36355.,
#        37786., 38629., 38929., 39618., 41597., 44144., 45210., 45851.,
#        46171., 46292., 48303., 50663., 51441., 52618., 54163., 56336.,
#        56709., 58347., 61512., 62881., 63131., 65462., 65930., 67112.,
#        67956., 68019., 72362., 73247., 74846., 75039., 75842., 77011.,
#        77758., 78486., 78831., 78854., 80628., 82083., 82100., 82299.,
#        83442., 85829., 87061., 87253., 92109., 92738., 94020., 95437.,
#        97098., 98565., 99223.]) * ms, [0.0 ms, 100000.0 ms])>]
# 83

# %% [markdown]
# ## Plot:

# %%
plot.Figure(
    #plot spikes for input population
    plot.Panel(spikes_input, yticks=True, markersize=5, xlim =(0, simtime)),
    
    #plot voltage for first ([0]) neuron
    plot.Panel(v_pop1, ylabel="Membrane potential (mV)", data_labels=[pop_1.label], yticks=True, xlim =(0, simtime)),
    
    #plot spikes for pop1 population
    plot.Panel(spikes_pop1, yticks=True, markersize=5, xlim =(0, simtime)),
    
    title="Simple Example",
    annotations="Simulated with {}".format(sim.name())
)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">
