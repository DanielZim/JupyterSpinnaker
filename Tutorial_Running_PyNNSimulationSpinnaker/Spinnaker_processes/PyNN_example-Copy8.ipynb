# %%
import pyNN.spiNNaker as sim
import pyNN.utility.plotting as plot
import matplotlib.pyplot as plt
# Out:
# Detected PyNN version 0.9.4 and Neo version 0.6.1

# %% [markdown]
# ## Setting up the simulator:

# %%
sim.setup(timestep=1.0)
sim.set_number_of_neurons_per_core(sim.IF_curr_exp, 100)
# Out:
# 2019-05-17 14:42:50 INFO: Read cfg files: /home/jovyan/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/interface/spinnaker.cfg, /home/jovyan/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/spynnaker.cfg, /home/jovyan/.spynnaker.cfg
# 2019-05-17 14:42:50 INFO: Will search these locations for binaries: /home/jovyan/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/common_model_binaries : /home/jovyan/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/model_binaries
# 2019-05-17 14:42:50 INFO: Setting time scale factor to 1.0.
# 2019-05-17 14:42:50 INFO: Setting machine time step to 1000 micro-seconds.
# ['/home/jovyan/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/interface/spinnaker.cfg', '/home/jovyan/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/spynnaker.cfg', '/home/jovyan/.spynnaker.cfg']

# %% [markdown]
# ## Setting up the populations:

# %%
# Define Input neuron
# input = sim.Population(1,sim.SpikeSourceArray(spike_times=[10, 200,210,215, 217, 220, 225, 325, 456]),label="input")
#input = sim.Population(1,sim.SpikeSourceArray(spike_times=[2]),label="input")
#input = sim.Population(1, sim.SpikeSourcePoisson(rate=0), label="Input")
input = sim.Population(1, sim.SpikeSourcePoisson(), label="Input")

# Define output neuron
pop_1 = sim.Population(1,sim.IF_curr_exp(),label="pop_1")

# Connect Input Neuron with Output neuron
input_proj=sim.Projection(input,pop_1,sim.OneToOneConnector(),synapse_type=sim.StaticSynapse(weight=5,delay=1))

pop_1.record(["spikes","v"])
input.record(["spikes"])

# %% [markdown]
# ## Simulate:

# %%
simtime = 100000
sim.run(simtime)
# Out:
# 2019-05-17 14:42:50 INFO: Simulating for 100 1000ms timesteps using a hardware timestep of 1000000us
# 2019-05-17 14:42:50 INFO: Starting execution process
# 2019-05-17 14:42:56 INFO: Time 0:00:04.058304 taken by SpallocMaxMachineGenerator
# Pre allocating resources for Extra Monitor support vertices
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:06 INFO: Time 0:00:10.391149 taken by PreAllocateResourcesForExtraMonitorSupport
# Partitioning graph vertices
# |0%                          50%                         100%|
#  ============================================================
# Partitioning graph edges
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:14 INFO: Time 0:00:07.455266 taken by PartitionAndPlacePartitioner
# Created spalloc job 4642682
# 2019-05-17 14:43:14 INFO: Created spalloc job 4642682
# Waiting for board power commands to complete.
# 2019-05-17 14:43:14 INFO: Waiting for board power commands to complete.
# 2019-05-17 14:43:19 INFO: Time 0:00:05.053557 taken by SpallocAllocator
# 2019-05-17 14:43:19 INFO: Creating transceiver for 10.11.193.145
# 2019-05-17 14:43:19 INFO: Working out if machine is booted
# 2019-05-17 14:43:23 INFO: Attempting to boot machine
# 2019-05-17 14:43:28 INFO: Found board with version [Version: SC&MP 3.2.4 at SpiNNaker:0:0:0 (built Mon Mar  4 14:26:32 2019)]
# 2019-05-17 14:43:28 INFO: Machine communication successful
# 2019-05-17 14:43:28 INFO: Detected a machine on IP address 10.11.193.145 which has 816 cores and 120 links
# 2019-05-17 14:43:28 INFO: Time 0:00:09.637198 taken by MachineGenerator
# Generating partitioner report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:28 INFO: Time 0:00:00.009400 taken by PartitionerReport
# 2019-05-17 14:43:28 INFO: Time 0:00:00.000209 taken by NetworkSpecificationReport
# Allocating virtual identifiers
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:28 INFO: Time 0:00:00.039487 taken by MallocBasedChipIDAllocator
# Inserting extra monitors into graphs
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:28 INFO: Time 0:00:00.023397 taken by InsertExtraMonitorVerticesToGraphs
# Writing the board chip report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:28 INFO: Time 0:00:00.002687 taken by BoardChipReport
# Filtering edges
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:28 INFO: Time 0:00:00.022774 taken by GraphEdgeFilter
# Placing graph vertices
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:28 INFO: Time 0:00:00.027747 taken by OneToOnePlacer
# Inserting edges between vertices which require FR speed up functionality.
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:28 INFO: Time 0:00:00.046620 taken by InsertEdgesToExtraMonitorFunctionality
# generating fixed router routes.
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:29 INFO: Time 0:00:00.048418 taken by FixedRouteRouter
# Generating placement report
# |0%                          50%                         100%|
#  ============================================================
# Generating placement by core report
# |0%                          50%                         100%|
#  ============================================================
# Generating SDRAM usage report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:29 INFO: Time 0:00:00.140594 taken by PlacerReportWithApplicationGraph
# Routing
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:29 INFO: Time 0:00:00.018251 taken by RigMCRoute
# Discovering tags
# |0%                          50%                         100%|
#  ============================================================
# Allocating tags
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:29 INFO: Time 0:00:00.051368 taken by BasicTagAllocator
# Reporting Tags
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:29 INFO: Time 0:00:00.011064 taken by TagReport
# Getting number of keys required by each edge using application graph
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:29 INFO: Time 0:00:00.040102 taken by EdgeToNKeysMapper
# Getting constraints for application graph
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:29 INFO: Time 0:00:00.039846 taken by ProcessPartitionConstraints
# Allocating routing keys
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:29 INFO: Time 0:00:00.013787 taken by MallocBasedRoutingInfoAllocator
# Generating Routing info report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:29 INFO: Time 0:00:00.038448 taken by routingInfoReports
# Generating routing tables
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:29 INFO: Time 0:00:00.037322 taken by BasicRoutingTableGenerator
# Finding executable start types
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:29 INFO: Time 0:00:00.041231 taken by LocateExecutableStartType
# Initialising buffers
# |0%                          50%                         100%|
#  =========================================================2019-05-17 14:43:29 INFO: Listening for packets using tag 2 on 0.0.0.0:49647
# ===
# 2019-05-17 14:43:29 INFO: Time 0:00:00.040749 taken by BufferManagerCreator
# Generating data specifications
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:29 INFO: Time 0:00:00.065117 taken by SpynnakerDataSpecificationWriter
# Preparing Routing Tables
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:29 INFO: Time 0:00:00.011511 taken by RoutingSetup
# Finding binaries
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:29 INFO: Time 0:00:00.040893 taken by GraphBinaryGatherer
# Running routing table compression on chip
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:30 INFO: Time 0:00:01.230080 taken by MundyOnChipRouterCompression
# Generating Router table report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:30 INFO: Time 0:00:00.009939 taken by unCompressedRoutingTableReports
# loading fixed routes
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:30 INFO: Time 0:00:00.042249 taken by LoadFixedRoutes
# Clearing tags
# |0%                          50%                         100%|
#  ============================================================
# Loading Tags
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:30 INFO: Time 0:00:00.021370 taken by TagsLoader
# Writing data
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:31 INFO: Time 0:00:00.047292 taken by WriteMemoryIOData
# Executing data specifications and loading data
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:31 INFO: Time 0:00:00.139200 taken by HostExecuteDataSpecification
# Expanding Synapses
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:31 INFO: Time 0:00:00.549943 taken by SynapseExpander
# Writing fixed route report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:31 INFO: Time 0:00:00.045462 taken by FixedRouteFromMachineReport
# Loading executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:33 INFO: Time 0:00:01.441174 taken by LoadExecutableImages
# Reading Routing Tables from Machine
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:33 INFO: Time 0:00:00.013755 taken by RoutingTableFromMachineReport
# Generating compressed router table report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:33 INFO: Time 0:00:00.008006 taken by compressedRoutingTableReports
# Generating comparison of router table report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:33 INFO: Time 0:00:00.008062 taken by comparisonOfRoutingTablesReport
# 2019-05-17 14:43:33 INFO: Running for 1 steps for a total of 100000.0ms
# 2019-05-17 14:43:33 INFO: Run 1 of 1
# Updating run time
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:33 INFO: Time 0:00:00.030924 taken by ChipRuntimeUpdater
# Creating database
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:33 INFO: Time 0:00:00.044904 taken by DatabaseInterface
# 2019-05-17 14:43:33 INFO: ** Notifying external sources that the database is ready for reading **
# 2019-05-17 14:43:33 INFO: Time 0:00:00.000755 taken by NotificationProtocol
# 2019-05-17 14:43:33 INFO: *** Running simulation... ***
# Loading buffers (0 bytes)
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:43:33 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2019-05-17 14:43:33 INFO: ** Sending start / resume message to external sources to state the simulation has started or resumed. **
# 2019-05-17 14:43:33 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2019-05-17 14:43:33 INFO: Application started; waiting 100.1s for it to stop
# 2019-05-17 14:45:13 INFO: ** Sending pause / stop message to external sources to state the simulation has been paused or stopped. **
# 2019-05-17 14:45:13 INFO: Time 0:01:40.192220 taken by ApplicationRunner
# Extracting buffers from the last run
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:45:13 INFO: Time 0:00:00.296319 taken by BufferExtractor
# Getting provenance data from machine graph
# |0%                          50%                         100%|
#  ============================================================
# Getting provenance data from application graph
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:45:13 INFO: Time 0:00:00.097857 taken by GraphProvenanceGatherer
# Getting provenance data
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:45:13 INFO: Time 0:00:00.035386 taken by PlacementsProvenanceGatherer
# Getting Router Provenance
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:45:14 INFO: Time 0:00:00.061030 taken by RouterProvenanceGatherer
# Getting profile data
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 14:45:14 INFO: Time 0:00:00.028000 taken by ProfileDataGatherer
# 100000.0

# %% [markdown]
# ## Print:

# %%
# Input neuron
neo_input=input.get_data(variables=["spikes"])

spikes_input=neo_input.segments[0].spiketrains
print(spikes_input)
print( len(spikes_input[0]) )

# Pop1 neuron
neo_pop1=pop_1.get_data(variables=["spikes","v"])

v_pop1=neo_pop1.segments[0].filter(name='v')[0]
#print(v_pop1)

spikes_pop1=neo_pop1.segments[0].spiketrains
#print(spikes_pop1)

sim.end()
# Out:
# Getting spikes for Input
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for pop_1
# |0%                          50%                         100%|
#  ============================================================
# Getting v for pop_1
# |0%                          50%                         100%|
#  ============================================================
# [<SpikeTrain(array([  263.,   526.,   575.,  2372.,  4483.,  6490.,  6530.,  7034.,
#         8993.,  9195., 12673., 16787., 17286., 19298., 19624., 19669.,
#        22521., 23671., 25458., 27077., 27939., 28353., 29195., 30529.,
#        32086., 34683., 35074., 35594., 36497., 36583., 36934., 37020.,
#        37731., 38521., 40961., 43410., 43720., 43766., 44391., 45628.,
#        46032., 46713., 47215., 49199., 49881., 50912., 51643., 53891.,
#        54310., 54843., 55108., 55250., 55272., 55982., 58689., 59887.,
#        62070., 63558., 64146., 64309., 64383., 64739., 65722., 66515.,
#        68797., 70010., 70306., 70897., 71019., 72551., 72798., 76204.,
#        76869., 81305., 81970., 82409., 82445., 85387., 86003., 86274.,
#        86344., 86433., 86978., 87105., 90341., 90840., 92667., 93816.,
#        94162., 95890., 96111., 97061., 99510.]) * ms, [0.0 ms, 100000.0 ms])>]
# 93

# %% [markdown]
# ## Plot:

# %%
plot.Figure(
    #plot spikes for input population
    plot.Panel(spikes_input, yticks=True, markersize=5, xlim =(0, simtime)),
    
    #plot voltage for first ([0]) neuron
    plot.Panel(v_pop1, ylabel="Membrane potential (mV)", data_labels=[pop_1.label], yticks=True, xlim =(0, simtime)),
    
    #plot spikes for pop1 population
    plot.Panel(spikes_pop1, yticks=True, markersize=5, xlim =(0, simtime)),
    
    title="Simple Example",
    annotations="Simulated with {}".format(sim.name())
)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">
