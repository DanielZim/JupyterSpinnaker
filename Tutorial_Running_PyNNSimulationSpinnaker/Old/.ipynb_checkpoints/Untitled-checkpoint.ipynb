# %%
import pyNN.spiNNaker as sim
import pyNN.utility.plotting as plot
import matplotlib.pyplot as plt
# Out:
# Detected PyNN version 0.9.4 and Neo version 0.6.1

# %% [markdown]
# ## Setting up the simulator:

# %%
sim.setup(timestep=1.0)
sim.set_number_of_neurons_per_core(sim.IF_curr_exp, 100)
# Out:
# 2019-05-17 12:00:04 INFO: Read cfg files: /home/jovyan/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/interface/spinnaker.cfg, /home/jovyan/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/spynnaker.cfg, /home/jovyan/.spynnaker.cfg
# 2019-05-17 12:00:04 INFO: Will search these locations for binaries: /home/jovyan/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/common_model_binaries : /home/jovyan/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/model_binaries
# 2019-05-17 12:00:04 INFO: Setting time scale factor to 1.0.
# 2019-05-17 12:00:04 INFO: Setting machine time step to 1000 micro-seconds.
# ['/home/jovyan/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/interface/spinnaker.cfg', '/home/jovyan/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/spynnaker.cfg', '/home/jovyan/.spynnaker.cfg']

# %% [markdown]
# ## Setting up the populations:

# %%
pop_1 = sim.Population(1,sim.IF_curr_exp(),label="pop_1")
input = sim.Population(1,sim.SpikeSourceArray(spike_times=[0]),label="input")
input_proj=sim.Projection(input,pop_1,sim.OneToOneConnector(),synapse_type=sim.StaticSynapse(weight=5,delay=1))

pop_1.record(["spikes","v"])

# %% [markdown]
# ## Simulate:

# %%
simtime = 10
sim.run(simtime)
# Out:
# 2019-05-17 12:00:07 INFO: Simulating for 1 1000ms timesteps using a hardware timestep of 1000000us
# 2019-05-17 12:00:07 INFO: Starting execution process
# 2019-05-17 12:00:11 INFO: Time 0:00:03.583041 taken by SpallocMaxMachineGenerator
# Pre allocating resources for Extra Monitor support vertices
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:21 INFO: Time 0:00:10.073337 taken by PreAllocateResourcesForExtraMonitorSupport
# Partitioning graph vertices
# |0%                          50%                         100%|
#  ============================================================
# Partitioning graph edges
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:28 INFO: Time 0:00:06.936330 taken by PartitionAndPlacePartitioner
# Created spalloc job 4640749
# 2019-05-17 12:00:28 INFO: Created spalloc job 4640749
# Waiting for board power commands to complete.
# 2019-05-17 12:00:28 INFO: Waiting for board power commands to complete.
# 2019-05-17 12:00:33 INFO: Time 0:00:05.045618 taken by SpallocAllocator
# 2019-05-17 12:00:33 INFO: Creating transceiver for 10.11.193.81
# 2019-05-17 12:00:33 INFO: Working out if machine is booted
# 2019-05-17 12:00:37 INFO: Attempting to boot machine
# 2019-05-17 12:00:43 INFO: Found board with version [Version: SC&MP 3.2.4 at SpiNNaker:0:0:0 (built Mon Mar  4 14:26:32 2019)]
# 2019-05-17 12:00:43 INFO: Machine communication successful
# 2019-05-17 12:00:43 INFO: Detected a machine on IP address 10.11.193.81 which has 816 cores and 120 links
# 2019-05-17 12:00:43 INFO: Time 0:00:09.641280 taken by MachineGenerator
# Generating partitioner report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:43 INFO: Time 0:00:00.012645 taken by PartitionerReport
# 2019-05-17 12:00:43 INFO: Time 0:00:00.000252 taken by NetworkSpecificationReport
# Allocating virtual identifiers
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:43 INFO: Time 0:00:00.064981 taken by MallocBasedChipIDAllocator
# Inserting extra monitors into graphs
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:43 INFO: Time 0:00:00.034825 taken by InsertExtraMonitorVerticesToGraphs
# Writing the board chip report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:43 INFO: Time 0:00:00.008737 taken by BoardChipReport
# Filtering edges
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:43 INFO: Time 0:00:00.035064 taken by GraphEdgeFilter
# Placing graph vertices
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:43 INFO: Time 0:00:00.039751 taken by OneToOnePlacer
# Inserting edges between vertices which require FR speed up functionality.
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:43 INFO: Time 0:00:00.053009 taken by InsertEdgesToExtraMonitorFunctionality
# generating fixed router routes.
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:43 INFO: Time 0:00:00.009435 taken by FixedRouteRouter
# Generating placement report
# |0%                          50%                         100%|
#  ============================================================
# Generating placement by core report
# |0%                          50%                         100%|
#  ============================================================
# Generating SDRAM usage report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:43 INFO: Time 0:00:00.118174 taken by PlacerReportWithApplicationGraph
# Routing
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:43 INFO: Time 0:00:00.013616 taken by RigMCRoute
# Discovering tags
# |0%                          50%                         100%|
#  ============================================================
# Allocating tags
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:43 INFO: Time 0:00:00.039899 taken by BasicTagAllocator
# Reporting Tags
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:43 INFO: Time 0:00:00.008492 taken by TagReport
# Getting number of keys required by each edge using application graph
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:43 INFO: Time 0:00:00.032439 taken by EdgeToNKeysMapper
# Getting constraints for application graph
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:43 INFO: Time 0:00:00.023875 taken by ProcessPartitionConstraints
# Allocating routing keys
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:43 INFO: Time 0:00:00.007466 taken by MallocBasedRoutingInfoAllocator
# Generating Routing info report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:43 INFO: Time 0:00:00.038907 taken by routingInfoReports
# Generating routing tables
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:44 INFO: Time 0:00:00.032142 taken by BasicRoutingTableGenerator
# Finding executable start types
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:44 INFO: Time 0:00:00.025881 taken by LocateExecutableStartType
# Initialising buffers
# |0%                          50%                         100%|
#  =========================================================2019-05-17 12:00:44 INFO: Listening for packets using tag 2 on 0.0.0.0:51141
# ===
# 2019-05-17 12:00:44 INFO: Time 0:00:00.037361 taken by BufferManagerCreator
# Generating data specifications
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:44 INFO: Time 0:00:00.061917 taken by SpynnakerDataSpecificationWriter
# Preparing Routing Tables
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:44 INFO: Time 0:00:00.011004 taken by RoutingSetup
# Finding binaries
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:44 INFO: Time 0:00:00.029817 taken by GraphBinaryGatherer
# Running routing table compression on chip
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:45 INFO: Time 0:00:01.236176 taken by MundyOnChipRouterCompression
# Generating Router table report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:45 INFO: Time 0:00:00.009524 taken by unCompressedRoutingTableReports
# loading fixed routes
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:45 INFO: Time 0:00:00.048838 taken by LoadFixedRoutes
# Clearing tags
# |0%                          50%                         100%|
#  ============================================================
# Loading Tags
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:45 INFO: Time 0:00:00.016799 taken by TagsLoader
# Writing data
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:45 INFO: Time 0:00:00.036245 taken by WriteMemoryIOData
# Executing data specifications and loading data
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:45 INFO: Time 0:00:00.173552 taken by HostExecuteDataSpecification
# Expanding Synapses
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:46 INFO: Time 0:00:00.541146 taken by SynapseExpander
# Writing fixed route report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:46 INFO: Time 0:00:00.051040 taken by FixedRouteFromMachineReport
# Loading executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:47 INFO: Time 0:00:01.493555 taken by LoadExecutableImages
# Reading Routing Tables from Machine
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:47 INFO: Time 0:00:00.016723 taken by RoutingTableFromMachineReport
# Generating compressed router table report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:47 INFO: Time 0:00:00.010388 taken by compressedRoutingTableReports
# Generating comparison of router table report
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:47 INFO: Time 0:00:00.009402 taken by comparisonOfRoutingTablesReport
# 2019-05-17 12:00:47 INFO: Running for 1 steps for a total of 10.0ms
# 2019-05-17 12:00:47 INFO: Run 1 of 1
# Updating run time
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:47 INFO: Time 0:00:00.030672 taken by ChipRuntimeUpdater
# 2019-05-17 12:00:47 INFO: Time 0:00:00.000195 taken by DatabaseInterface
# 2019-05-17 12:00:47 INFO: Time 0:00:00.000077 taken by NotificationProtocol
# 2019-05-17 12:00:47 INFO: *** Running simulation... ***
# Loading buffers (12 bytes)
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:48 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2019-05-17 12:00:48 INFO: ** Sending start / resume message to external sources to state the simulation has started or resumed. **
# 2019-05-17 12:00:48 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2019-05-17 12:00:48 INFO: Application started; waiting 0.11s for it to stop
# 2019-05-17 12:00:48 INFO: ** Sending pause / stop message to external sources to state the simulation has been paused or stopped. **
# 2019-05-17 12:00:48 INFO: Time 0:00:00.200179 taken by ApplicationRunner
# Extracting buffers from the last run
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:48 INFO: Time 0:00:00.088863 taken by BufferExtractor
# Getting provenance data from machine graph
# |0%                          50%                         100%|
#  ============================================================
# Getting provenance data from application graph
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:48 INFO: Time 0:00:00.099854 taken by GraphProvenanceGatherer
# Getting provenance data
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:48 INFO: Time 0:00:00.038132 taken by PlacementsProvenanceGatherer
# Getting Router Provenance
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:48 INFO: Time 0:00:00.058790 taken by RouterProvenanceGatherer
# Getting profile data
# |0%                          50%                         100%|
#  ============================================================
# 2019-05-17 12:00:48 INFO: Time 0:00:00.035388 taken by ProfileDataGatherer
# 10.0

# %% [markdown]
# ## Print:

# %%
neo=pop_1.get_data(variables=["spikes","v"])
spikes=neo.segments[0].spiketrains
print(spikes)
v=neo.segments[0].filter(name='v')[0]
print(v)
sim.end()
# Out:
# Getting spikes for pop_1
# |0%                          50%                         100%|
#  ============================================================
# Getting v for pop_1
# |0%                          50%                         100%|
#  ============================================================
# [<SpikeTrain(array([7.]) * ms, [0.0 ms, 10.0 ms])>]
# [[-65.        ]
#  [-65.        ]
#  [-60.58001709]
#  [-57.17681885]
#  [-54.59555054]
#  [-52.67724609]
#  [-51.29220581]
#  [-50.33474731]
#  [-65.        ]
#  [-65.        ]] mV

# %% [markdown]
# ## Plot:

# %%
plot.Figure(
    #plot voltage for first ([0]) neuron
    plot.Panel(v,ylabel="Membrane potential (mV)",data_labels=[pop_1.label],yticks=True,xlim=(0,simtime)),
    #plot spikes(or in this case spike)
    plot.Panel(spikes, yticks=True, markersize=5, xlim=(0, simtime)),
    title="Simple Example",
    annotations="Simulated with {}".format(sim.name())
)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">
