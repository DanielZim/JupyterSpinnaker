# %%
import platform
print(platform.python_version())
# Out:
# 3.7.1

# %%
import pybullet as p
import time
import pybullet_data

#physicsClient = p.connect(p.GUI)#or p.DIRECT for non-graphical version
physicsClient = p.connect(p.DIRECT)#or p.DIRECT for non-graphical version

p.setAdditionalSearchPath(pybullet_data.getDataPath()) #optionally
p.setGravity(0,0,-10)

planeId = p.loadURDF("plane.urdf")

#virtual_room = p.loadSDF("virtual_room.sdf")

cubeStartPos = [0,0,1]
cubeStartOrientation = p.getQuaternionFromEuler([0,0,0])

boxId = p.loadURDF("r2d2.urdf",cubeStartPos, cubeStartOrientation)

for i in range (100):
    p.stepSimulation()
    time.sleep(1./240.)
    
    
cubePos, cubeOrn = p.getBasePositionAndOrientation(boxId)

print(cubePos,cubeOrn)
p.disconnect()
# Out:
# (1.5400148641257287e-08, 1.497161425098085e-06, 0.47099233386544337) (-3.354586533985831e-08, 3.991249435559775e-09, 9.404116936754563e-08, 0.999999999999995)

# %%
#testrender.py is a bit slower than testrender_np.py: pixels are copied from C to Python one by one

import matplotlib.pyplot as plt
import pybullet
import time
import numpy as np  #to reshape for matplotlib

plt.ion()

img = [[1, 2, 3] * 50] * 100  #np.random.rand(200, 320)
#img = [tandard_normal((50,100))
image = plt.imshow(img, interpolation='none', animated=True, label="blah")
ax = plt.gca()

pybullet.connect(pybullet.DIRECT)

#pybullet.loadPlugin("eglRendererPlugin")
#pybullet.loadURDF("plane.urdf")
#pybullet.loadURDF("r2d2.urdf")

pybullet.setGravity(0, 0, -10)
camTargetPos = [0, 0, 0]
cameraUp = [0, 0, 1]
cameraPos = [1, 1, 1]

pitch = -10.0

roll = 0
upAxisIndex = 2
camDistance = 4
pixelWidth = 320
pixelHeight = 200
nearPlane = 0.01
farPlane = 100

fov = 60
print("test")

main_start = time.time()
while (1):
  for yaw in range(0, 360, 10):
    pybullet.stepSimulation()
    start = time.time()
    viewMatrix = pybullet.computeViewMatrixFromYawPitchRoll(camTargetPos, camDistance, yaw, pitch,
                                                            roll, upAxisIndex)
    aspect = pixelWidth / pixelHeight
    projectionMatrix = pybullet.computeProjectionMatrixFOV(fov, aspect, nearPlane, farPlane)
    img_arr = pybullet.getCameraImage(pixelWidth,
                                      pixelHeight,
                                      viewMatrix,
                                      projectionMatrix,
                                      shadow=1,
                                      lightDirection=[1, 1, 1],
                                      renderer=pybullet.ER_BULLET_HARDWARE_OPENGL)
    stop = time.time()
    print("renderImage %f" % (stop - start))

    w = img_arr[0]  #width of the image, in pixels
    h = img_arr[1]  #height of the image, in pixels
    rgb = img_arr[2]  #color data RGB
    dep = img_arr[3]  #depth data
    #print(rgb)
    print('width = %d height = %d' % (w, h))

    #note that sending the data using imshow to matplotlib is really slow, so we use set_data

    #plt.imshow(rgb,interpolation='none')

    #reshape is needed
    np_img_arr = np.reshape(rgb, (h, w, 4))
    np_img_arr = np_img_arr * (1. / 255.)

    image.set_data(np_img_arr)
    ax.plot([0])
    #plt.draw()
    #plt.show()
    plt.pause(0.01)

main_stop = time.time()

print("Total time %f" % (main_stop - main_start))

pybullet.resetSimulation()
# Out:
# test
# renderImage 0.002038
# width = 320 height = 200
# renderImage 0.001743
# width = 320 height = 200
# renderImage 0.001710
# width = 320 height = 200
# renderImage 0.001711
# width = 320 height = 200
# renderImage 0.001696
# width = 320 height = 200
# renderImage 0.001835
# width = 320 height = 200
# renderImage 0.001723
# width = 320 height = 200
# renderImage 0.001880
# width = 320 height = 200
# renderImage 0.001933
# width = 320 height = 200
# renderImage 0.001870
# width = 320 height = 200
# renderImage 0.001687
# width = 320 height = 200
# renderImage 0.001687
# width = 320 height = 200
# renderImage 0.001897
# width = 320 height = 200
# renderImage 0.001963
# width = 320 height = 200
# renderImage 0.001976
# width = 320 height = 200
# renderImage 0.001839
# width = 320 height = 200
# renderImage 0.002063
# width = 320 height = 200
# renderImage 0.001939
# width = 320 height = 200
# renderImage 0.001921
# width = 320 height = 200
# renderImage 0.001943
# width = 320 height = 200
# renderImage 0.001775
# width = 320 height = 200
# renderImage 0.002041
# width = 320 height = 200
# renderImage 0.001789
# width = 320 height = 200
# renderImage 0.001855
# width = 320 height = 200
# renderImage 0.001805
# width = 320 height = 200
# renderImage 0.001690
# width = 320 height = 200
# renderImage 0.001708
# width = 320 height = 200
# renderImage 0.001824
# width = 320 height = 200
# renderImage 0.001708
# width = 320 height = 200
# renderImage 0.001795
# width = 320 height = 200
# renderImage 0.001724
# width = 320 height = 200
# renderImage 0.001693
# width = 320 height = 200
# renderImage 0.001696
# width = 320 height = 200
# renderImage 0.001693
# width = 320 height = 200
# renderImage 0.001754
# width = 320 height = 200
# renderImage 0.001688
# width = 320 height = 200
# renderImage 0.002010
# width = 320 height = 200
# renderImage 0.001729
# width = 320 height = 200
# renderImage 0.001718
# width = 320 height = 200
# renderImage 0.001774
# width = 320 height = 200
# renderImage 0.001888
# width = 320 height = 200
# renderImage 0.001688
# width = 320 height = 200
# renderImage 0.001711
# width = 320 height = 200
# renderImage 0.001761
# width = 320 height = 200
# renderImage 0.001846
# width = 320 height = 200
# renderImage 0.001760
# width = 320 height = 200
# renderImage 0.001709
# width = 320 height = 200
# renderImage 0.001858
# width = 320 height = 200
# renderImage 0.001698
# width = 320 height = 200
# renderImage 0.002045
# width = 320 height = 200
# renderImage 0.001686
# width = 320 height = 200
# renderImage 0.001742
# width = 320 height = 200
# renderImage 0.001738
# width = 320 height = 200
# renderImage 0.001765
# width = 320 height = 200
# renderImage 0.001697
# width = 320 height = 200
# renderImage 0.001807
# width = 320 height = 200
# renderImage 0.001687
# width = 320 height = 200
# renderImage 0.001712
# width = 320 height = 200
# renderImage 0.001730
# width = 320 height = 200
# renderImage 0.001703
# width = 320 height = 200
# renderImage 0.001807
# width = 320 height = 200
# renderImage 0.001755
# width = 320 height = 200
# renderImage 0.001942
# width = 320 height = 200
# renderImage 0.001697
# width = 320 height = 200
# renderImage 0.001742
# width = 320 height = 200
# renderImage 0.001687
# width = 320 height = 200
# renderImage 0.001896
# width = 320 height = 200
# renderImage 0.001690
# width = 320 height = 200
# renderImage 0.001754
# width = 320 height = 200
# renderImage 0.001995
# width = 320 height = 200
# renderImage 0.001791
# width = 320 height = 200
# renderImage 0.001732
# width = 320 height = 200
# renderImage 0.001711
# width = 320 height = 200
# renderImage 0.001722
# width = 320 height = 200
# renderImage 0.001886
# width = 320 height = 200
# renderImage 0.001722
# width = 320 height = 200
# renderImage 0.001866
# width = 320 height = 200
# renderImage 0.001990
# width = 320 height = 200
# renderImage 0.001745
# width = 320 height = 200
# renderImage 0.001712
# width = 320 height = 200
# renderImage 0.001683
# width = 320 height = 200
# renderImage 0.001806
# width = 320 height = 200
# renderImage 0.001793
# width = 320 height = 200
# renderImage 0.001869
# width = 320 height = 200
# renderImage 0.001699
# width = 320 height = 200
# renderImage 0.001698
# width = 320 height = 200
# renderImage 0.001698
# width = 320 height = 200
# renderImage 0.001703
# width = 320 height = 200
# renderImage 0.001683
# width = 320 height = 200
# renderImage 0.001711
# width = 320 height = 200
# renderImage 0.001925
# width = 320 height = 200
# renderImage 0.001730
# width = 320 height = 200
# renderImage 0.001738
# width = 320 height = 200
# renderImage 0.001760
# width = 320 height = 200
# renderImage 0.001902
# width = 320 height = 200
# renderImage 0.001705
# width = 320 height = 200
# renderImage 0.001768
# width = 320 height = 200
# renderImage 0.001690
# width = 320 height = 200
# renderImage 0.001732
# width = 320 height = 200
# renderImage 0.001888
# width = 320 height = 200
# renderImage 0.001723
# width = 320 height = 200
# renderImage 0.001846
# width = 320 height = 200
# renderImage 0.001716
# width = 320 height = 200
# renderImage 0.001734
# width = 320 height = 200
# renderImage 0.001806
# width = 320 height = 200
# renderImage 0.001732
# width = 320 height = 200
# renderImage 0.001712
# width = 320 height = 200
# renderImage 0.001743
# width = 320 height = 200
# renderImage 0.001810
# width = 320 height = 200
# renderImage 0.001803
# width = 320 height = 200
# renderImage 0.001721
# width = 320 height = 200
# renderImage 0.001809
# width = 320 height = 200
# renderImage 0.001684
# width = 320 height = 200
# renderImage 0.001774
# width = 320 height = 200
# renderImage 0.001688
# width = 320 height = 200
# renderImage 0.001764
# width = 320 height = 200
# renderImage 0.001736
# width = 320 height = 200
# renderImage 0.001915
# width = 320 height = 200
# renderImage 0.001839
# width = 320 height = 200
# renderImage 0.001838
# width = 320 height = 200
# renderImage 0.001770
# width = 320 height = 200
# renderImage 0.001715
# width = 320 height = 200
# renderImage 0.001710
# width = 320 height = 200
# renderImage 0.001703
# width = 320 height = 200
# renderImage 0.001801
# width = 320 height = 200
# renderImage 0.001834
# width = 320 height = 200
# renderImage 0.001712
# width = 320 height = 200
# renderImage 0.001732
# width = 320 height = 200
# renderImage 0.001723
# width = 320 height = 200
# renderImage 0.001693
# width = 320 height = 200
# renderImage 0.001920
# width = 320 height = 200
# renderImage 0.001908
# width = 320 height = 200
# renderImage 0.001812
# width = 320 height = 200
# renderImage 0.001726
# width = 320 height = 200
# renderImage 0.001812
# width = 320 height = 200
# renderImage 0.001702
# width = 320 height = 200
# renderImage 0.001695
# width = 320 height = 200
# renderImage 0.001703
# width = 320 height = 200
# renderImage 0.001684
# width = 320 height = 200
# renderImage 0.001758
# width = 320 height = 200
# renderImage 0.001683
# width = 320 height = 200
# renderImage 0.001838
# width = 320 height = 200
# renderImage 0.001681
# width = 320 height = 200
# renderImage 0.001718
# width = 320 height = 200
# renderImage 0.001727
# width = 320 height = 200
# renderImage 0.001714
# width = 320 height = 200
# renderImage 0.001688
# width = 320 height = 200
# renderImage 0.001755
# width = 320 height = 200
# renderImage 0.001934
# width = 320 height = 200
# renderImage 0.001694
# width = 320 height = 200
# renderImage 0.001740
# width = 320 height = 200
# renderImage 0.001707
# width = 320 height = 200
# renderImage 0.001783
# width = 320 height = 200
# renderImage 0.001685
# width = 320 height = 200
# renderImage 0.001754
# width = 320 height = 200
# renderImage 0.001822
# width = 320 height = 200
# renderImage 0.001723
# width = 320 height = 200
# renderImage 0.001772
# width = 320 height = 200
# renderImage 0.001696
# width = 320 height = 200
# renderImage 0.001789
# width = 320 height = 200
# renderImage 0.001772
# width = 320 height = 200
# renderImage 0.001706
# width = 320 height = 200
# renderImage 0.001839
# width = 320 height = 200
# renderImage 0.001711
# width = 320 height = 200
# renderImage 0.001694
# width = 320 height = 200
# renderImage 0.001714
# width = 320 height = 200
# renderImage 0.001696
# width = 320 height = 200
# renderImage 0.001747
# width = 320 height = 200
# renderImage 0.001967
# width = 320 height = 200
# renderImage 0.001688
# width = 320 height = 200
# renderImage 0.001794
# width = 320 height = 200
# renderImage 0.001733
# width = 320 height = 200
# renderImage 0.001913
# width = 320 height = 200
# renderImage 0.001750
# width = 320 height = 200
# renderImage 0.001754
# width = 320 height = 200
# renderImage 0.001782
# width = 320 height = 200
# renderImage 0.001715
# width = 320 height = 200
# renderImage 0.001918
# width = 320 height = 200
# renderImage 0.001749
# width = 320 height = 200
# renderImage 0.001892
# width = 320 height = 200
# renderImage 0.001750
# width = 320 height = 200
# renderImage 0.001719
# width = 320 height = 200
# renderImage 0.001723
# width = 320 height = 200
# renderImage 0.001690
# width = 320 height = 200
# renderImage 0.001792
# width = 320 height = 200
# renderImage 0.001999
# width = 320 height = 200
# renderImage 0.001763
# width = 320 height = 200
# renderImage 0.001772
# width = 320 height = 200
# renderImage 0.001828
# width = 320 height = 200
# renderImage 0.001858
# width = 320 height = 200
# renderImage 0.001914
# width = 320 height = 200
# renderImage 0.001806
# width = 320 height = 200
# renderImage 0.001731
# width = 320 height = 200
# renderImage 0.001877
# width = 320 height = 200
# renderImage 0.001684
# width = 320 height = 200
# renderImage 0.001714
# width = 320 height = 200
# renderImage 0.001691
# width = 320 height = 200
# renderImage 0.001677
# width = 320 height = 200
# renderImage 0.001712
# width = 320 height = 200
# renderImage 0.001820
# width = 320 height = 200
# renderImage 0.001702
# width = 320 height = 200
# renderImage 0.001756
# width = 320 height = 200
# renderImage 0.001701
# width = 320 height = 200
# renderImage 0.001702
# width = 320 height = 200
# renderImage 0.001829
# width = 320 height = 200
# renderImage 0.001688
# width = 320 height = 200
# renderImage 0.001709
# width = 320 height = 200
# renderImage 0.001693
# width = 320 height = 200
# renderImage 0.001690
# width = 320 height = 200
# renderImage 0.001850
# width = 320 height = 200
# renderImage 0.001691
# width = 320 height = 200
# renderImage 0.001714
# width = 320 height = 200
# renderImage 0.001715
# width = 320 height = 200
# renderImage 0.001944
# width = 320 height = 200
# renderImage 0.001751
# width = 320 height = 200
# renderImage 0.001837
# width = 320 height = 200
# renderImage 0.001918
# width = 320 height = 200
# renderImage 0.001673
# width = 320 height = 200
# renderImage 0.001675
# width = 320 height = 200
# renderImage 0.001688
# width = 320 height = 200
# renderImage 0.001685
# width = 320 height = 200
# renderImage 0.001692
# width = 320 height = 200
# renderImage 0.001758
# width = 320 height = 200
# renderImage 0.001691
# width = 320 height = 200
# renderImage 0.001785
# width = 320 height = 200
# renderImage 0.001873
# width = 320 height = 200
# renderImage 0.001795
# width = 320 height = 200
# renderImage 0.001776
# width = 320 height = 200
# renderImage 0.001760
# width = 320 height = 200
# renderImage 0.001710
# width = 320 height = 200
# renderImage 0.001781
# width = 320 height = 200
# renderImage 0.001894
# width = 320 height = 200
# renderImage 0.001686
# width = 320 height = 200
# renderImage 0.001864
# width = 320 height = 200
# renderImage 0.001712
# width = 320 height = 200
# renderImage 0.001715
# width = 320 height = 200
# renderImage 0.001769
# width = 320 height = 200
# renderImage 0.001700
# width = 320 height = 200
# renderImage 0.001709
# width = 320 height = 200
# renderImage 0.001916
# width = 320 height = 200
# renderImage 0.001764
# width = 320 height = 200
# renderImage 0.001862
# width = 320 height = 200
# renderImage 0.001747
# width = 320 height = 200
# renderImage 0.001795
# width = 320 height = 200
# renderImage 0.001685
# width = 320 height = 200
# renderImage 0.001805
# width = 320 height = 200
# renderImage 0.001714
# width = 320 height = 200
# renderImage 0.001786
# width = 320 height = 200
# renderImage 0.001745
# width = 320 height = 200
# renderImage 0.001719
# width = 320 height = 200
# renderImage 0.001705
# width = 320 height = 200
# renderImage 0.001784
# width = 320 height = 200
# renderImage 0.001820
# width = 320 height = 200
# renderImage 0.001690
# width = 320 height = 200
# renderImage 0.001884
# width = 320 height = 200
# renderImage 0.001916
# width = 320 height = 200
# renderImage 0.001825
# width = 320 height = 200
# renderImage 0.002009
# width = 320 height = 200
# renderImage 0.001718
# width = 320 height = 200
# renderImage 0.001805
# width = 320 height = 200
# renderImage 0.001688
# width = 320 height = 200
# renderImage 0.001784
# width = 320 height = 200
# renderImage 0.001693
# width = 320 height = 200
# renderImage 0.001688
# width = 320 height = 200
# renderImage 0.001888
# width = 320 height = 200
# renderImage 0.001755
# width = 320 height = 200
# renderImage 0.001745
# width = 320 height = 200
# renderImage 0.001715
# width = 320 height = 200
# renderImage 0.001706
# width = 320 height = 200
# renderImage 0.001697
# width = 320 height = 200
# renderImage 0.001840
# width = 320 height = 200
# renderImage 0.001780
# width = 320 height = 200
# renderImage 0.001696
# width = 320 height = 200
# renderImage 0.001806
# width = 320 height = 200
# renderImage 0.001691
# width = 320 height = 200
# renderImage 0.001994
# width = 320 height = 200
# renderImage 0.001751
# width = 320 height = 200
# renderImage 0.001862
# width = 320 height = 200
# renderImage 0.001733
# width = 320 height = 200
# renderImage 0.001685
# width = 320 height = 200
# renderImage 0.001693
# width = 320 height = 200
# renderImage 0.001693
# width = 320 height = 200
# renderImage 0.001748
# width = 320 height = 200
# renderImage 0.001699
# width = 320 height = 200
# renderImage 0.001711
# width = 320 height = 200
# renderImage 0.001693
# width = 320 height = 200
# renderImage 0.001711
# width = 320 height = 200
# renderImage 0.001694
# width = 320 height = 200
# renderImage 0.001720
# width = 320 height = 200
# renderImage 0.001867
# width = 320 height = 200
# renderImage 0.001761
# width = 320 height = 200
# renderImage 0.001855
# width = 320 height = 200
# renderImage 0.001909
# width = 320 height = 200
# renderImage 0.001815
# width = 320 height = 200
# renderImage 0.001875
# width = 320 height = 200
# renderImage 0.001812
# width = 320 height = 200
# renderImage 0.001803
# width = 320 height = 200
# renderImage 0.001783
# width = 320 height = 200
# renderImage 0.001791
# width = 320 height = 200
# renderImage 0.001778
# width = 320 height = 200
# renderImage 0.001798
# width = 320 height = 200
# renderImage 0.001789
# width = 320 height = 200
# renderImage 0.002039
# width = 320 height = 200
# renderImage 0.001803
# width = 320 height = 200
# renderImage 0.001794
# width = 320 height = 200
# renderImage 0.001783
# width = 320 height = 200
# renderImage 0.001801
# width = 320 height = 200
# renderImage 0.002006
# width = 320 height = 200
# renderImage 0.001830
# width = 320 height = 200
# renderImage 0.001937
# width = 320 height = 200
# renderImage 0.001764
# width = 320 height = 200
# renderImage 0.001969
# width = 320 height = 200
# renderImage 0.001822
# width = 320 height = 200
# renderImage 0.001725
# width = 320 height = 200
# renderImage 0.001806
# width = 320 height = 200
# renderImage 0.001813
# width = 320 height = 200
# renderImage 0.001939
# width = 320 height = 200
# renderImage 0.001713
# width = 320 height = 200
# renderImage 0.001708
# width = 320 height = 200
# renderImage 0.001682
# width = 320 height = 200
# renderImage 0.001836
# width = 320 height = 200
# renderImage 0.001737
# width = 320 height = 200
# renderImage 0.001764
# width = 320 height = 200
# renderImage 0.002021
# width = 320 height = 200
# renderImage 0.001694
# width = 320 height = 200
# renderImage 0.001885
# width = 320 height = 200
# renderImage 0.001728
# width = 320 height = 200
# renderImage 0.001817
# width = 320 height = 200
# renderImage 0.001806
# width = 320 height = 200
# renderImage 0.001713
# width = 320 height = 200
# renderImage 0.001801
# width = 320 height = 200
# renderImage 0.001817
# width = 320 height = 200
# renderImage 0.001712
# width = 320 height = 200
# renderImage 0.001715
# width = 320 height = 200
# renderImage 0.001690
# width = 320 height = 200
# renderImage 0.001919
# width = 320 height = 200
# renderImage 0.001901
# width = 320 height = 200
# renderImage 0.001692
# width = 320 height = 200
# renderImage 0.001834
# width = 320 height = 200
# renderImage 0.001878
# width = 320 height = 200
# renderImage 0.001874
# width = 320 height = 200
# renderImage 0.001715
# width = 320 height = 200
# renderImage 0.001685
# width = 320 height = 200
# renderImage 0.001778
# width = 320 height = 200
# renderImage 0.001898
# width = 320 height = 200
# renderImage 0.001739
# width = 320 height = 200
# renderImage 0.001886
# width = 320 height = 200
# renderImage 0.001792
# width = 320 height = 200
# renderImage 0.001707
# width = 320 height = 200
# renderImage 0.001687
# width = 320 height = 200
# renderImage 0.001713
# width = 320 height = 200
# renderImage 0.001748
# width = 320 height = 200
# renderImage 0.001791
# width = 320 height = 200
# renderImage 0.001692
# width = 320 height = 200
# renderImage 0.001702
# width = 320 height = 200
# renderImage 0.001795
# width = 320 height = 200
# renderImage 0.001786
# width = 320 height = 200
# renderImage 0.001870
# width = 320 height = 200
# renderImage 0.001687
# width = 320 height = 200
# renderImage 0.001752
# width = 320 height = 200
# renderImage 0.001890
# width = 320 height = 200
# renderImage 0.001749
# width = 320 height = 200
# renderImage 0.001778
# width = 320 height = 200
# renderImage 0.001966
# width = 320 height = 200
# renderImage 0.001726
# width = 320 height = 200
# renderImage 0.001815
# width = 320 height = 200
# renderImage 0.001683
# width = 320 height = 200
# renderImage 0.001946
# width = 320 height = 200
# renderImage 0.001802
# width = 320 height = 200
# renderImage 0.001865
# width = 320 height = 200
# renderImage 0.001802
# width = 320 height = 200
# renderImage 0.001747
# width = 320 height = 200
# renderImage 0.001705
# width = 320 height = 200
# renderImage 0.001740
# width = 320 height = 200
# renderImage 0.001793
# width = 320 height = 200
# renderImage 0.001764
# width = 320 height = 200
# renderImage 0.001701
# width = 320 height = 200
# renderImage 0.001764
# width = 320 height = 200
# renderImage 0.001734
# width = 320 height = 200
# renderImage 0.001727
# width = 320 height = 200
# renderImage 0.001854
# width = 320 height = 200
# renderImage 0.001694
# width = 320 height = 200
# renderImage 0.001698
# width = 320 height = 200
# renderImage 0.001685
# width = 320 height = 200
# renderImage 0.001719
# width = 320 height = 200
# renderImage 0.001720
# width = 320 height = 200
# renderImage 0.001701
# width = 320 height = 200
# renderImage 0.001826
# width = 320 height = 200
# renderImage 0.001825
# width = 320 height = 200
# renderImage 0.001794
# width = 320 height = 200
# renderImage 0.001688
# width = 320 height = 200
# renderImage 0.001699
# width = 320 height = 200
# renderImage 0.001930
# width = 320 height = 200
# renderImage 0.001905
# width = 320 height = 200
# renderImage 0.001824
# width = 320 height = 200
# renderImage 0.001691
# width = 320 height = 200
# renderImage 0.001802
# width = 320 height = 200
# renderImage 0.001807
# width = 320 height = 200
# renderImage 0.001816
# width = 320 height = 200
# renderImage 0.001828
# width = 320 height = 200
# renderImage 0.001708
# width = 320 height = 200
# renderImage 0.001829
# width = 320 height = 200
# renderImage 0.001833
# width = 320 height = 200
# renderImage 0.001731
# width = 320 height = 200
# renderImage 0.001919
# width = 320 height = 200
# renderImage 0.001693
# width = 320 height = 200
# renderImage 0.001712
# width = 320 height = 200
# renderImage 0.001741
# width = 320 height = 200
# renderImage 0.001898
# width = 320 height = 200
# renderImage 0.001719
# width = 320 height = 200
# renderImage 0.001684
# width = 320 height = 200
# renderImage 0.001939
# width = 320 height = 200
# renderImage 0.001679
# width = 320 height = 200
# renderImage 0.001994
# width = 320 height = 200
# renderImage 0.001692
# width = 320 height = 200
# renderImage 0.001708
# width = 320 height = 200
# renderImage 0.001688
# width = 320 height = 200
# renderImage 0.001965
# width = 320 height = 200
# renderImage 0.001738
# width = 320 height = 200
# renderImage 0.001950
# width = 320 height = 200
# renderImage 0.001726
# width = 320 height = 200
# renderImage 0.001737
# width = 320 height = 200
# renderImage 0.001934
# width = 320 height = 200
# renderImage 0.001724
# width = 320 height = 200
# renderImage 0.001681
# width = 320 height = 200
# renderImage 0.001680
# width = 320 height = 200
# renderImage 0.001683
# width = 320 height = 200
# renderImage 0.001684
# width = 320 height = 200
# renderImage 0.001695
# width = 320 height = 200
# renderImage 0.001886
# width = 320 height = 200
# renderImage 0.001707
# width = 320 height = 200
# renderImage 0.001725
# width = 320 height = 200
# renderImage 0.001692
# width = 320 height = 200
# renderImage 0.001867
# width = 320 height = 200
# renderImage 0.001858
# width = 320 height = 200
# renderImage 0.001703
# width = 320 height = 200
# renderImage 0.001771
# width = 320 height = 200
# renderImage 0.001810
# width = 320 height = 200
# renderImage 0.001992
# width = 320 height = 200
# renderImage 0.001788
# width = 320 height = 200
# renderImage 0.001700
# width = 320 height = 200
# renderImage 0.001745
# width = 320 height = 200
# renderImage 0.001747
# width = 320 height = 200
# renderImage 0.001790
# width = 320 height = 200
# renderImage 0.001988
# width = 320 height = 200
# renderImage 0.001812
# width = 320 height = 200
# renderImage 0.001754
# width = 320 height = 200
# renderImage 0.001700
# width = 320 height = 200
# renderImage 0.001822
# width = 320 height = 200
# renderImage 0.001680
# width = 320 height = 200
# renderImage 0.001886
# width = 320 height = 200
# renderImage 0.001689
# width = 320 height = 200
# renderImage 0.001744
# width = 320 height = 200
# renderImage 0.001793
# width = 320 height = 200
# renderImage 0.001765
# width = 320 height = 200
# renderImage 0.001996
# width = 320 height = 200
# renderImage 0.001794
# width = 320 height = 200
# renderImage 0.001782
# width = 320 height = 200
# renderImage 0.001767
# width = 320 height = 200
# renderImage 0.001852
# width = 320 height = 200
# renderImage 0.001707
# width = 320 height = 200
# renderImage 0.001693
# width = 320 height = 200
# renderImage 0.001734
# width = 320 height = 200
# renderImage 0.001909
# width = 320 height = 200
# renderImage 0.001811
# width = 320 height = 200
# renderImage 0.001764
# width = 320 height = 200
# renderImage 0.001793
# width = 320 height = 200
# renderImage 0.001864
# width = 320 height = 200
# renderImage 0.001788
# width = 320 height = 200
# renderImage 0.001781
# width = 320 height = 200
# renderImage 0.001803
# width = 320 height = 200
# renderImage 0.001752
# width = 320 height = 200
# renderImage 0.001956
# width = 320 height = 200
# renderImage 0.001712
# width = 320 height = 200
# renderImage 0.001795
# width = 320 height = 200
# renderImage 0.001781
# width = 320 height = 200
# renderImage 0.001725
# width = 320 height = 200
# renderImage 0.001699
# width = 320 height = 200
# renderImage 0.001816
# width = 320 height = 200
# renderImage 0.001683
# width = 320 height = 200
# renderImage 0.001772
# width = 320 height = 200
# renderImage 0.001850
# width = 320 height = 200
# renderImage 0.001699
# width = 320 height = 200
# renderImage 0.001729
# width = 320 height = 200
# renderImage 0.001835
# width = 320 height = 200
# renderImage 0.001887
# width = 320 height = 200
# renderImage 0.001811
# width = 320 height = 200
# renderImage 0.001688
# width = 320 height = 200
# renderImage 0.001719
# width = 320 height = 200
# renderImage 0.001698
# width = 320 height = 200
# renderImage 0.001714
# width = 320 height = 200
# renderImage 0.001699
# width = 320 height = 200
# renderImage 0.001710
# width = 320 height = 200
# renderImage 0.001734
# width = 320 height = 200
# renderImage 0.001715
# width = 320 height = 200
# renderImage 0.001849
# width = 320 height = 200
# renderImage 0.001772
# width = 320 height = 200
# renderImage 0.001774
# width = 320 height = 200
# renderImage 0.001761
# width = 320 height = 200
# renderImage 0.001713
# width = 320 height = 200
# renderImage 0.001772
# width = 320 height = 200
# renderImage 0.001776
# width = 320 height = 200
# renderImage 0.001895
# width = 320 height = 200
# renderImage 0.001800
# width = 320 height = 200
# renderImage 0.001754
# width = 320 height = 200
# renderImage 0.001828
# width = 320 height = 200
# renderImage 0.001754
# width = 320 height = 200
# renderImage 0.001699
# width = 320 height = 200
# renderImage 0.001806
# width = 320 height = 200
# renderImage 0.001744
# width = 320 height = 200
# renderImage 0.001904
# width = 320 height = 200
# renderImage 0.001862
# width = 320 height = 200
# renderImage 0.001885
# width = 320 height = 200
# renderImage 0.001710
# width = 320 height = 200
# renderImage 0.001683
# width = 320 height = 200
# renderImage 0.001696
# width = 320 height = 200
# renderImage 0.001711
# width = 320 height = 200
# renderImage 0.001788
# width = 320 height = 200
# renderImage 0.001776
# width = 320 height = 200
# renderImage 0.001772
# width = 320 height = 200
# renderImage 0.001706
# width = 320 height = 200
# renderImage 0.001698
# width = 320 height = 200
# renderImage 0.001902
# width = 320 height = 200
# renderImage 0.001724
# width = 320 height = 200
# renderImage 0.001826
# width = 320 height = 200
# renderImage 0.001842
# width = 320 height = 200
# renderImage 0.001772
# width = 320 height = 200
# renderImage 0.001691
# width = 320 height = 200
# renderImage 0.001749
# width = 320 height = 200
# renderImage 0.001714
# width = 320 height = 200
# renderImage 0.001751
# width = 320 height = 200
# renderImage 0.001714
# width = 320 height = 200
# renderImage 0.001695
# width = 320 height = 200
# renderImage 0.001753
# width = 320 height = 200
# renderImage 0.001798
# width = 320 height = 200
# renderImage 0.001755
# width = 320 height = 200
# renderImage 0.001769
# width = 320 height = 200
# renderImage 0.001712
# width = 320 height = 200
# renderImage 0.001756
# width = 320 height = 200
# renderImage 0.001724
# width = 320 height = 200
# renderImage 0.001692
# width = 320 height = 200
# renderImage 0.001684
# width = 320 height = 200
# renderImage 0.001719
# width = 320 height = 200
# renderImage 0.001719
# width = 320 height = 200
# renderImage 0.001709
# width = 320 height = 200
# renderImage 0.001734
# width = 320 height = 200
# renderImage 0.001768
# width = 320 height = 200
# renderImage 0.001963
# width = 320 height = 200
# renderImage 0.001749
# width = 320 height = 200
# renderImage 0.001722
# width = 320 height = 200
# renderImage 0.001901
# width = 320 height = 200
# renderImage 0.001741
# width = 320 height = 200
# renderImage 0.001702
# width = 320 height = 200
# renderImage 0.001851
# width = 320 height = 200
# renderImage 0.001689
# width = 320 height = 200
# renderImage 0.001714
# width = 320 height = 200
# renderImage 0.001738
# width = 320 height = 200
# renderImage 0.001846
# width = 320 height = 200
# renderImage 0.001715
# width = 320 height = 200
# renderImage 0.001684
# width = 320 height = 200
# renderImage 0.001711
# width = 320 height = 200
# renderImage 0.001812
# width = 320 height = 200
# renderImage 0.001732
# width = 320 height = 200
# renderImage 0.001694
# width = 320 height = 200
# renderImage 0.001700
# width = 320 height = 200
# renderImage 0.001803
# width = 320 height = 200
# renderImage 0.001846
# width = 320 height = 200
# renderImage 0.001713
# width = 320 height = 200
# renderImage 0.001720
# width = 320 height = 200
# renderImage 0.001674
# width = 320 height = 200
# renderImage 0.001826
# width = 320 height = 200
# renderImage 0.001752
# width = 320 height = 200
# renderImage 0.001809
# width = 320 height = 200
# renderImage 0.001713
# width = 320 height = 200
# renderImage 0.001775
# width = 320 height = 200
# renderImage 0.001750
# width = 320 height = 200
# renderImage 0.001715
# width = 320 height = 200
# renderImage 0.001762
# width = 320 height = 200
# renderImage 0.001770
# width = 320 height = 200
# renderImage 0.001856
# width = 320 height = 200
# renderImage 0.001925
# width = 320 height = 200
# renderImage 0.001686
# width = 320 height = 200
# renderImage 0.001734
# width = 320 height = 200
# renderImage 0.001700
# width = 320 height = 200
# renderImage 0.001739
# width = 320 height = 200
# renderImage 0.001689
# width = 320 height = 200
# renderImage 0.001710
# width = 320 height = 200
# renderImage 0.001762
# width = 320 height = 200
# renderImage 0.001711
# width = 320 height = 200
# renderImage 0.001746
# width = 320 height = 200
# renderImage 0.001957
# width = 320 height = 200
# renderImage 0.001873
# width = 320 height = 200
# renderImage 0.001972
# width = 320 height = 200
# renderImage 0.001864
# width = 320 height = 200
# renderImage 0.001704
# width = 320 height = 200
# renderImage 0.001764
# width = 320 height = 200
# renderImage 0.001858
# width = 320 height = 200
# renderImage 0.001772
# width = 320 height = 200
# renderImage 0.001693
# width = 320 height = 200
# renderImage 0.001715
# width = 320 height = 200
# renderImage 0.001708
# width = 320 height = 200
# renderImage 0.001834
# width = 320 height = 200
# renderImage 0.001713
# width = 320 height = 200
# renderImage 0.001832
# width = 320 height = 200
# renderImage 0.001804
# width = 320 height = 200
# renderImage 0.001785
# width = 320 height = 200
# renderImage 0.001682
# width = 320 height = 200
# renderImage 0.001728
# width = 320 height = 200
# renderImage 0.001802
# width = 320 height = 200
# renderImage 0.001704
# width = 320 height = 200
# renderImage 0.001893
# width = 320 height = 200
# renderImage 0.001698
# width = 320 height = 200
# renderImage 0.001776
# width = 320 height = 200
# renderImage 0.001928
# width = 320 height = 200
# renderImage 0.001678
# width = 320 height = 200
# renderImage 0.001709
# width = 320 height = 200
# renderImage 0.001683
# width = 320 height = 200
# renderImage 0.001694
# width = 320 height = 200
# renderImage 0.001708
# width = 320 height = 200
# renderImage 0.001688
# width = 320 height = 200
# renderImage 0.001934
# width = 320 height = 200
# renderImage 0.001765
# width = 320 height = 200
# renderImage 0.001865
# width = 320 height = 200
# renderImage 0.001796
# width = 320 height = 200
# renderImage 0.001964
# width = 320 height = 200
# renderImage 0.001706
# width = 320 height = 200
# renderImage 0.001839
# width = 320 height = 200
# renderImage 0.001703
# width = 320 height = 200
# renderImage 0.001712
# width = 320 height = 200
# renderImage 0.001689
# width = 320 height = 200
# renderImage 0.001709
# width = 320 height = 200
# renderImage 0.001754
# width = 320 height = 200
# renderImage 0.001691
# width = 320 height = 200
# renderImage 0.001700
# width = 320 height = 200
# renderImage 0.001690
# width = 320 height = 200
# renderImage 0.001928
# width = 320 height = 200
# renderImage 0.001753
# width = 320 height = 200
# renderImage 0.001709
# width = 320 height = 200
# renderImage 0.001780
# width = 320 height = 200
# renderImage 0.001811
# width = 320 height = 200
# renderImage 0.001730
# width = 320 height = 200
# renderImage 0.001765
# width = 320 height = 200
# renderImage 0.001691
# width = 320 height = 200
# renderImage 0.002042
# width = 320 height = 200
# renderImage 0.001737
# width = 320 height = 200
# renderImage 0.001688
# width = 320 height = 200
# renderImage 0.001713
# width = 320 height = 200
# renderImage 0.001695
# width = 320 height = 200
# renderImage 0.001708
# width = 320 height = 200
# renderImage 0.001732
# width = 320 height = 200
# renderImage 0.002020
# width = 320 height = 200
# renderImage 0.001884
# width = 320 height = 200
# renderImage 0.001845
# width = 320 height = 200
# renderImage 0.001799
# width = 320 height = 200
# renderImage 0.001973
# width = 320 height = 200
# renderImage 0.001694
# width = 320 height = 200
# renderImage 0.001714
# width = 320 height = 200
# renderImage 0.001804
# width = 320 height = 200
# renderImage 0.001702
# width = 320 height = 200
# renderImage 0.001756
# width = 320 height = 200
# renderImage 0.001690
# width = 320 height = 200
# renderImage 0.001724
# width = 320 height = 200
# renderImage 0.001736
# width = 320 height = 200
# renderImage 0.001693
# width = 320 height = 200
# renderImage 0.001702
# width = 320 height = 200
# renderImage 0.001723
# width = 320 height = 200
# renderImage 0.001923
# width = 320 height = 200
# renderImage 0.001730
# width = 320 height = 200
# renderImage 0.001727
# width = 320 height = 200
# renderImage 0.001760
# width = 320 height = 200
# renderImage 0.001864
# width = 320 height = 200
# renderImage 0.001743
# width = 320 height = 200
# renderImage 0.001694
# width = 320 height = 200
# renderImage 0.001689
# width = 320 height = 200
# renderImage 0.001960
# width = 320 height = 200
# renderImage 0.001775
# width = 320 height = 200
# renderImage 0.001868
# width = 320 height = 200
# renderImage 0.001714
# width = 320 height = 200
# renderImage 0.001688
# width = 320 height = 200
# renderImage 0.001729
# width = 320 height = 200
# renderImage 0.001771
# width = 320 height = 200
# renderImage 0.001694
# width = 320 height = 200
# renderImage 0.001763
# width = 320 height = 200
# renderImage 0.001858
# width = 320 height = 200
# renderImage 0.001729
# width = 320 height = 200
# renderImage 0.001983
# width = 320 height = 200
# renderImage 0.001822
# width = 320 height = 200
# renderImage 0.001784
# width = 320 height = 200
# renderImage 0.001717
# width = 320 height = 200
# renderImage 0.001755
# width = 320 height = 200
# renderImage 0.001694
# width = 320 height = 200
# renderImage 0.001840
# width = 320 height = 200
# renderImage 0.001926
# width = 320 height = 200
# renderImage 0.001691
# width = 320 height = 200
# renderImage 0.001768
# width = 320 height = 200
# renderImage 0.001699
# width = 320 height = 200
# renderImage 0.001849
# width = 320 height = 200
# renderImage 0.001708
# width = 320 height = 200
# renderImage 0.001709
# width = 320 height = 200
# renderImage 0.001718
# width = 320 height = 200
# renderImage 0.001762
# width = 320 height = 200
# renderImage 0.001760
# width = 320 height = 200
# renderImage 0.001839
# width = 320 height = 200
# renderImage 0.001815
# width = 320 height = 200
# renderImage 0.001694
# width = 320 height = 200
# renderImage 0.001707
# width = 320 height = 200
# renderImage 0.001687
# width = 320 height = 200
# renderImage 0.001778
# width = 320 height = 200
# renderImage 0.001708
# width = 320 height = 200
# renderImage 0.001778
# width = 320 height = 200
# renderImage 0.001832
# width = 320 height = 200
# renderImage 0.001792
# width = 320 height = 200
# renderImage 0.001904
# width = 320 height = 200
# renderImage 0.001903
# width = 320 height = 200
# renderImage 0.001698
# width = 320 height = 200
# renderImage 0.001701
# width = 320 height = 200
# renderImage 0.001705
# width = 320 height = 200
# renderImage 0.001793
# width = 320 height = 200
# renderImage 0.001697
# width = 320 height = 200
# renderImage 0.001901
# width = 320 height = 200
# renderImage 0.001818
# width = 320 height = 200
# renderImage 0.001712
# width = 320 height = 200
# renderImage 0.001724
# width = 320 height = 200
# renderImage 0.001966
# width = 320 height = 200
# renderImage 0.001762
# width = 320 height = 200
# renderImage 0.001901
# width = 320 height = 200
# renderImage 0.001736
# width = 320 height = 200
# renderImage 0.001803
# width = 320 height = 200
# renderImage 0.001729
# width = 320 height = 200
# renderImage 0.001717
# width = 320 height = 200
# renderImage 0.001976
# width = 320 height = 200
# renderImage 0.001718
# width = 320 height = 200
# renderImage 0.001717
# width = 320 height = 200
# renderImage 0.001770
# width = 320 height = 200
# renderImage 0.001718
# width = 320 height = 200
# renderImage 0.001718
# width = 320 height = 200
# renderImage 0.001692
# width = 320 height = 200
# renderImage 0.001755
# width = 320 height = 200
# renderImage 0.001910
# width = 320 height = 200
# renderImage 0.001699
# width = 320 height = 200
# renderImage 0.001916
# width = 320 height = 200
# renderImage 0.001782
# width = 320 height = 200
# renderImage 0.001915
# width = 320 height = 200
# renderImage 0.001724
# width = 320 height = 200
# renderImage 0.001778
# width = 320 height = 200
# renderImage 0.001808
# width = 320 height = 200
# renderImage 0.001757
# width = 320 height = 200
# renderImage 0.001744
# width = 320 height = 200
# renderImage 0.001683
# width = 320 height = 200
# renderImage 0.001712
# width = 320 height = 200
# renderImage 0.001971
# width = 320 height = 200
# renderImage 0.001755
# width = 320 height = 200
# renderImage 0.001873
# width = 320 height = 200
# renderImage 0.001770
# width = 320 height = 200
# renderImage 0.001695
# width = 320 height = 200
# renderImage 0.001812
# width = 320 height = 200
# renderImage 0.001699
# width = 320 height = 200
# renderImage 0.001716
# width = 320 height = 200
# renderImage 0.001941
# width = 320 height = 200
# renderImage 0.001691
# width = 320 height = 200
# renderImage 0.001814
# width = 320 height = 200
# renderImage 0.001717
# width = 320 height = 200
# renderImage 0.001909
# width = 320 height = 200
# renderImage 0.001772
# width = 320 height = 200
# renderImage 0.001748
# width = 320 height = 200
# renderImage 0.001968
# width = 320 height = 200
# renderImage 0.001824
# width = 320 height = 200
# renderImage 0.001695
# width = 320 height = 200
# renderImage 0.001840
# width = 320 height = 200
# renderImage 0.001730
# width = 320 height = 200
# renderImage 0.001873
# width = 320 height = 200
# renderImage 0.001936
# width = 320 height = 200
# renderImage 0.001724
# width = 320 height = 200
# renderImage 0.001819
# width = 320 height = 200
# renderImage 0.001961
# width = 320 height = 200
# renderImage 0.001859
# width = 320 height = 200
# renderImage 0.001802
# width = 320 height = 200
# renderImage 0.001789
# width = 320 height = 200
# renderImage 0.001978
# width = 320 height = 200
# renderImage 0.001794
# width = 320 height = 200
# renderImage 0.001831
# width = 320 height = 200
# renderImage 0.001845
# width = 320 height = 200
# renderImage 0.001814
# width = 320 height = 200
# renderImage 0.001922
# width = 320 height = 200
# renderImage 0.001790
# width = 320 height = 200
# renderImage 0.001811
# width = 320 height = 200
# renderImage 0.002011
# width = 320 height = 200
# renderImage 0.001968
# width = 320 height = 200
# renderImage 0.001877
# width = 320 height = 200
# renderImage 0.001928
# width = 320 height = 200
# renderImage 0.001820
# width = 320 height = 200
# renderImage 0.001704
# width = 320 height = 200
# renderImage 0.001812
# width = 320 height = 200
# renderImage 0.001820
# width = 320 height = 200
# renderImage 0.001812
# width = 320 height = 200
# renderImage 0.001788
# width = 320 height = 200
# renderImage 0.001815
# width = 320 height = 200
# renderImage 0.001812
# width = 320 height = 200
# renderImage 0.002062
# width = 320 height = 200
# renderImage 0.001958
# width = 320 height = 200
# renderImage 0.002033
# width = 320 height = 200
# renderImage 0.001862
# width = 320 height = 200
# renderImage 0.001792
# width = 320 height = 200
# renderImage 0.001800
# width = 320 height = 200
# renderImage 0.001786
# width = 320 height = 200
# renderImage 0.001785
# width = 320 height = 200
# renderImage 0.001814
# width = 320 height = 200
# renderImage 0.002041
# width = 320 height = 200
# renderImage 0.001789
# width = 320 height = 200
# renderImage 0.001817
# width = 320 height = 200
# renderImage 0.001815
# width = 320 height = 200
# renderImage 0.001809
# width = 320 height = 200
# renderImage 0.001735
# width = 320 height = 200
# renderImage 0.001758
# width = 320 height = 200
# renderImage 0.001699
# width = 320 height = 200
# renderImage 0.001712
# width = 320 height = 200
# renderImage 0.001688
# width = 320 height = 200
# renderImage 0.001827
# width = 320 height = 200
# renderImage 0.001715
# width = 320 height = 200
# renderImage 0.001825
# width = 320 height = 200
# renderImage 0.001764
# width = 320 height = 200
# renderImage 0.001711
# width = 320 height = 200
# renderImage 0.001762
# width = 320 height = 200
# renderImage 0.001696
# width = 320 height = 200
# renderImage 0.001724
# width = 320 height = 200
# renderImage 0.001740
# width = 320 height = 200
# renderImage 0.001715
# width = 320 height = 200
# renderImage 0.001749
# width = 320 height = 200
# renderImage 0.001832
# width = 320 height = 200
# renderImage 0.001794
# width = 320 height = 200
# renderImage 0.001887
# width = 320 height = 200
# renderImage 0.001792
# width = 320 height = 200
# renderImage 0.001822
# width = 320 height = 200
# renderImage 0.001808
# width = 320 height = 200
# renderImage 0.001846
# width = 320 height = 200
# renderImage 0.001810
# width = 320 height = 200
# renderImage 0.001811
# width = 320 height = 200
# renderImage 0.001790
# width = 320 height = 200
# renderImage 0.001800
# width = 320 height = 200
# renderImage 0.001827
# width = 320 height = 200
# renderImage 0.001785
# width = 320 height = 200
# renderImage 0.001951
# width = 320 height = 200
# renderImage 0.001799
# width = 320 height = 200
# renderImage 0.001745
# width = 320 height = 200
# renderImage 0.001735
# width = 320 height = 200
# renderImage 0.001796
# width = 320 height = 200
# renderImage 0.001819
# width = 320 height = 200
# renderImage 0.001787
# width = 320 height = 200
# renderImage 0.001904
# width = 320 height = 200
# renderImage 0.002038
# width = 320 height = 200
# renderImage 0.001991
# width = 320 height = 200
# renderImage 0.001793
# width = 320 height = 200
# renderImage 0.001926
# width = 320 height = 200
# renderImage 0.002059
# width = 320 height = 200
# renderImage 0.001802
# width = 320 height = 200
# renderImage 0.001808
# width = 320 height = 200
# renderImage 0.001823
# width = 320 height = 200
# renderImage 0.001770
# width = 320 height = 200
# renderImage 0.001767
# width = 320 height = 200
# renderImage 0.001706
# width = 320 height = 200
# renderImage 0.001873
# width = 320 height = 200
# renderImage 0.001928
# width = 320 height = 200
# renderImage 0.002037
# width = 320 height = 200
# renderImage 0.001791
# width = 320 height = 200
# renderImage 0.001832
# width = 320 height = 200
# renderImage 0.001868
# width = 320 height = 200
# renderImage 0.001790
# width = 320 height = 200
# renderImage 0.002030
# width = 320 height = 200
# renderImage 0.001814
# width = 320 height = 200
# renderImage 0.001813
# width = 320 height = 200
# renderImage 0.001985
# width = 320 height = 200
# renderImage 0.001819
# width = 320 height = 200
# renderImage 0.002025
# width = 320 height = 200
# renderImage 0.001836
# width = 320 height = 200
# renderImage 0.001878
# width = 320 height = 200
# renderImage 0.001810
# width = 320 height = 200
# renderImage 0.001817
# width = 320 height = 200
# renderImage 0.001810
# width = 320 height = 200
# renderImage 0.001784
# width = 320 height = 200
# renderImage 0.001800
# width = 320 height = 200
# renderImage 0.001791
# width = 320 height = 200
# renderImage 0.001782
# width = 320 height = 200
# renderImage 0.001830
# width = 320 height = 200
# renderImage 0.001795
# width = 320 height = 200
# renderImage 0.001868
# width = 320 height = 200
# renderImage 0.001843
# width = 320 height = 200
# renderImage 0.001789
# width = 320 height = 200
# renderImage 0.001798
# width = 320 height = 200
# renderImage 0.001798
# width = 320 height = 200
# renderImage 0.001717
# width = 320 height = 200
# renderImage 0.001884
# width = 320 height = 200
# renderImage 0.001906
# width = 320 height = 200
# renderImage 0.001739
# width = 320 height = 200
# renderImage 0.001688
# width = 320 height = 200
# renderImage 0.001942
# width = 320 height = 200
# renderImage 0.001868
# width = 320 height = 200
# renderImage 0.001768
# width = 320 height = 200
# renderImage 0.001680
# width = 320 height = 200
# renderImage 0.001733
# width = 320 height = 200
# renderImage 0.001763
# width = 320 height = 200
# renderImage 0.001870
# width = 320 height = 200
# renderImage 0.001713
# width = 320 height = 200
# renderImage 0.001815
# width = 320 height = 200
# renderImage 0.001815
# width = 320 height = 200
# renderImage 0.001801
# width = 320 height = 200
# renderImage 0.001692
# width = 320 height = 200
# renderImage 0.001779
# width = 320 height = 200
# renderImage 0.001902
# width = 320 height = 200
# renderImage 0.001735
# width = 320 height = 200
# renderImage 0.001692
# width = 320 height = 200
# renderImage 0.001710
# width = 320 height = 200
# renderImage 0.001693
# width = 320 height = 200
# renderImage 0.001831
# width = 320 height = 200
# renderImage 0.001772
# width = 320 height = 200
# renderImage 0.001933
# width = 320 height = 200
# renderImage 0.001891
# width = 320 height = 200
# renderImage 0.001716
# width = 320 height = 200
# renderImage 0.002004
# width = 320 height = 200
# renderImage 0.001814
# width = 320 height = 200
# renderImage 0.001730
# width = 320 height = 200
# renderImage 0.002100
# width = 320 height = 200
# renderImage 0.001724
# width = 320 height = 200
# renderImage 0.001714
# width = 320 height = 200
# renderImage 0.001689
# width = 320 height = 200
# renderImage 0.001697
# width = 320 height = 200
# renderImage 0.001701
# width = 320 height = 200
# renderImage 0.001699
# width = 320 height = 200
# renderImage 0.001860
# width = 320 height = 200
# renderImage 0.001719
# width = 320 height = 200
# renderImage 0.001759
# width = 320 height = 200
# renderImage 0.001764
# width = 320 height = 200
# renderImage 0.001788
# width = 320 height = 200
# renderImage 0.001846
# width = 320 height = 200
# renderImage 0.001749
# width = 320 height = 200
# renderImage 0.001870
# width = 320 height = 200
# renderImage 0.002027
# width = 320 height = 200
# renderImage 0.001745
# width = 320 height = 200
# renderImage 0.001838
# width = 320 height = 200
# renderImage 0.001780
# width = 320 height = 200
# renderImage 0.001709
# width = 320 height = 200
# renderImage 0.001950
# width = 320 height = 200
# renderImage 0.001910
# width = 320 height = 200
# renderImage 0.001872
# width = 320 height = 200
# renderImage 0.001811
# width = 320 height = 200
# renderImage 0.001722
# width = 320 height = 200
# renderImage 0.001719
# width = 320 height = 200
# renderImage 0.001785
# width = 320 height = 200
# renderImage 0.001891
# width = 320 height = 200
# renderImage 0.001774
# width = 320 height = 200
# renderImage 0.001710
# width = 320 height = 200
# renderImage 0.001759
# width = 320 height = 200
# renderImage 0.001811
# width = 320 height = 200
# renderImage 0.001700
# width = 320 height = 200
# renderImage 0.001753
# width = 320 height = 200
# renderImage 0.001702
# width = 320 height = 200
# renderImage 0.001803
# width = 320 height = 200
# renderImage 0.001790
# width = 320 height = 200
# renderImage 0.001786
# width = 320 height = 200
# renderImage 0.001724
# width = 320 height = 200
# renderImage 0.001830
# width = 320 height = 200
# renderImage 0.001705
# width = 320 height = 200
# renderImage 0.001763
# width = 320 height = 200
# renderImage 0.001805
# width = 320 height = 200
# renderImage 0.001730
# width = 320 height = 200
# renderImage 0.001714
# width = 320 height = 200
# renderImage 0.001715
# width = 320 height = 200
# renderImage 0.001733
# width = 320 height = 200
# renderImage 0.001910
# width = 320 height = 200
# renderImage 0.001740
# width = 320 height = 200
# renderImage 0.001801
# width = 320 height = 200
# renderImage 0.001888
# width = 320 height = 200
# renderImage 0.001703
# width = 320 height = 200
# renderImage 0.001777
# width = 320 height = 200
# renderImage 0.001756
# width = 320 height = 200
# renderImage 0.001730
# width = 320 height = 200
# renderImage 0.001710
# width = 320 height = 200
# renderImage 0.001703
# width = 320 height = 200
# renderImage 0.001728
# width = 320 height = 200
# renderImage 0.001817
# width = 320 height = 200
# renderImage 0.001918
# width = 320 height = 200
# renderImage 0.001918
# width = 320 height = 200
# renderImage 0.002035
# width = 320 height = 200
# renderImage 0.001904
# width = 320 height = 200
# renderImage 0.001738
# width = 320 height = 200
# renderImage 0.001877
# width = 320 height = 200
# renderImage 0.001781
# width = 320 height = 200
# renderImage 0.001911
# width = 320 height = 200
# renderImage 0.001763
# width = 320 height = 200
# renderImage 0.001729
# width = 320 height = 200
# renderImage 0.001824
# width = 320 height = 200
# renderImage 0.001766
# width = 320 height = 200
# renderImage 0.001943
# width = 320 height = 200
# renderImage 0.001979
# width = 320 height = 200
# renderImage 0.001763
# width = 320 height = 200
# renderImage 0.001723
# width = 320 height = 200
# renderImage 0.001707
# width = 320 height = 200
# renderImage 0.001706
# width = 320 height = 200
# renderImage 0.001804
# width = 320 height = 200
# renderImage 0.001803
# width = 320 height = 200
# renderImage 0.001723
# width = 320 height = 200
# renderImage 0.001899
# width = 320 height = 200
# renderImage 0.001803
# width = 320 height = 200
# renderImage 0.001817
# width = 320 height = 200
# renderImage 0.001798
# width = 320 height = 200
# renderImage 0.001993
# width = 320 height = 200
# renderImage 0.001897
# width = 320 height = 200
# renderImage 0.002048
# width = 320 height = 200
# renderImage 0.002025
# width = 320 height = 200
# renderImage 0.001818
# width = 320 height = 200
# renderImage 0.001842
# width = 320 height = 200
# renderImage 0.001995
# width = 320 height = 200
# renderImage 0.001842
# width = 320 height = 200
# renderImage 0.001855
# width = 320 height = 200
# renderImage 0.002047
# width = 320 height = 200
# renderImage 0.001991
# width = 320 height = 200
# renderImage 0.001830
# width = 320 height = 200
# renderImage 0.002058
# width = 320 height = 200
# renderImage 0.001801
# width = 320 height = 200
# renderImage 0.001854
# width = 320 height = 200
# renderImage 0.001909
# width = 320 height = 200
# renderImage 0.001930
# width = 320 height = 200
# renderImage 0.001851
# width = 320 height = 200
# renderImage 0.001872
# width = 320 height = 200
# renderImage 0.001789
# width = 320 height = 200
# renderImage 0.001912
# width = 320 height = 200
# renderImage 0.001857
# width = 320 height = 200
# renderImage 0.001720
# width = 320 height = 200
# renderImage 0.001889
# width = 320 height = 200
# renderImage 0.001804
# width = 320 height = 200
# renderImage 0.001781
# width = 320 height = 200
# renderImage 0.001708
# width = 320 height = 200
# renderImage 0.001837
# width = 320 height = 200
# renderImage 0.001930
# width = 320 height = 200
# renderImage 0.001715
# width = 320 height = 200
# renderImage 0.001705
# width = 320 height = 200
# renderImage 0.001779
# width = 320 height = 200
# renderImage 0.001872
# width = 320 height = 200
# renderImage 0.001803
# width = 320 height = 200
# renderImage 0.001822
# width = 320 height = 200
# renderImage 0.001768
# width = 320 height = 200
# renderImage 0.002006
# width = 320 height = 200
# renderImage 0.002054
# width = 320 height = 200
# renderImage 0.001843
# width = 320 height = 200
# renderImage 0.002016
# width = 320 height = 200
# renderImage 0.001808
# width = 320 height = 200
# renderImage 0.001814
# width = 320 height = 200
# renderImage 0.001705
# width = 320 height = 200
# renderImage 0.001826
# width = 320 height = 200
# renderImage 0.001819
# width = 320 height = 200
# renderImage 0.001821
# width = 320 height = 200
# renderImage 0.001843
# width = 320 height = 200
# renderImage 0.001819
# width = 320 height = 200
# renderImage 0.001795
# width = 320 height = 200
# renderImage 0.001745
# width = 320 height = 200
# renderImage 0.001849
# width = 320 height = 200
# renderImage 0.001978
# width = 320 height = 200
# renderImage 0.001735
# width = 320 height = 200
# renderImage 0.001721
# width = 320 height = 200
# renderImage 0.001940
# width = 320 height = 200
# renderImage 0.001715
# width = 320 height = 200
# renderImage 0.001718
# width = 320 height = 200
# renderImage 0.001932
# width = 320 height = 200
# renderImage 0.001735
# width = 320 height = 200
# renderImage 0.001759
# width = 320 height = 200
# renderImage 0.001764
# width = 320 height = 200
# renderImage 0.001779
# width = 320 height = 200
# renderImage 0.001912
# width = 320 height = 200
# renderImage 0.001777
# width = 320 height = 200
# renderImage 0.001827
# width = 320 height = 200
# renderImage 0.001812
# width = 320 height = 200
# renderImage 0.001737
# width = 320 height = 200
# renderImage 0.001724
# width = 320 height = 200
# renderImage 0.001707
# width = 320 height = 200
# renderImage 0.001729
# width = 320 height = 200
# renderImage 0.001973
# width = 320 height = 200
# renderImage 0.001804
# width = 320 height = 200
# renderImage 0.001879
# width = 320 height = 200
# renderImage 0.001860
# width = 320 height = 200
# renderImage 0.001819
# width = 320 height = 200
# renderImage 0.001913
# width = 320 height = 200
# renderImage 0.001777
# width = 320 height = 200
# renderImage 0.001775
# width = 320 height = 200
# renderImage 0.001769
# width = 320 height = 200
# renderImage 0.001835
# width = 320 height = 200
# renderImage 0.001798
# width = 320 height = 200
# renderImage 0.001966
# width = 320 height = 200
# renderImage 0.001848
# width = 320 height = 200
# renderImage 0.001791
# width = 320 height = 200
# renderImage 0.001739
# width = 320 height = 200
# renderImage 0.001800
# width = 320 height = 200
# renderImage 0.001936
# width = 320 height = 200
# renderImage 0.001743
# width = 320 height = 200
# renderImage 0.001807
# width = 320 height = 200
# renderImage 0.002012
# width = 320 height = 200
# renderImage 0.001720
# width = 320 height = 200
# renderImage 0.001753
# width = 320 height = 200
# renderImage 0.001716
# width = 320 height = 200
# renderImage 0.001734
# width = 320 height = 200
# renderImage 0.001723
# width = 320 height = 200
# renderImage 0.001704
# width = 320 height = 200
# renderImage 0.001759
# width = 320 height = 200
# renderImage 0.001787
# width = 320 height = 200
# renderImage 0.001952
# width = 320 height = 200
# renderImage 0.001740
# width = 320 height = 200
# renderImage 0.001777
# width = 320 height = 200
# renderImage 0.001898
# width = 320 height = 200
# renderImage 0.001728
# width = 320 height = 200
# renderImage 0.001743
# width = 320 height = 200
# renderImage 0.001711
# width = 320 height = 200
# renderImage 0.001740
# width = 320 height = 200
# renderImage 0.001736
# width = 320 height = 200
# renderImage 0.001818
# width = 320 height = 200
# renderImage 0.001728
# width = 320 height = 200
# renderImage 0.001699
# width = 320 height = 200
# renderImage 0.001811
# width = 320 height = 200
# renderImage 0.001862
# width = 320 height = 200
# renderImage 0.001796
# width = 320 height = 200
# renderImage 0.001774
# width = 320 height = 200
# renderImage 0.001755
# width = 320 height = 200
# renderImage 0.001711
# width = 320 height = 200
# renderImage 0.001749
# width = 320 height = 200
# renderImage 0.001766
# width = 320 height = 200
# renderImage 0.001746
# width = 320 height = 200
# renderImage 0.001733
# width = 320 height = 200
# renderImage 0.001804
# width = 320 height = 200
# renderImage 0.001699
# width = 320 height = 200
# renderImage 0.001773
# width = 320 height = 200
# renderImage 0.002006
# width = 320 height = 200
# renderImage 0.001858
# width = 320 height = 200
# renderImage 0.001814
# width = 320 height = 200
# renderImage 0.001754
# width = 320 height = 200
# renderImage 0.001927
# width = 320 height = 200
# renderImage 0.001756
# width = 320 height = 200
# renderImage 0.001702
# width = 320 height = 200
# renderImage 0.001960
# width = 320 height = 200
# renderImage 0.001730
# width = 320 height = 200
# renderImage 0.001801
# width = 320 height = 200
# renderImage 0.001727
# width = 320 height = 200
# renderImage 0.001730
# width = 320 height = 200
# renderImage 0.001701
# width = 320 height = 200
# renderImage 0.001875
# width = 320 height = 200
# renderImage 0.001714
# width = 320 height = 200
# renderImage 0.001705
# width = 320 height = 200
# renderImage 0.001792
# width = 320 height = 200
# renderImage 0.001788
# width = 320 height = 200
# renderImage 0.001719
# width = 320 height = 200
# renderImage 0.001858
# width = 320 height = 200
# renderImage 0.001829
# width = 320 height = 200
# renderImage 0.001716
# width = 320 height = 200
# renderImage 0.001727
# width = 320 height = 200
# renderImage 0.002007
# width = 320 height = 200
# renderImage 0.001713
# width = 320 height = 200
# renderImage 0.001827
# width = 320 height = 200
# renderImage 0.001937
# width = 320 height = 200
# renderImage 0.003067
# width = 320 height = 200
# renderImage 0.001886
# width = 320 height = 200
# renderImage 0.001793
# width = 320 height = 200
# renderImage 0.001998
# width = 320 height = 200
# renderImage 0.001850
# width = 320 height = 200
# renderImage 0.001713
# width = 320 height = 200
# renderImage 0.001928
# width = 320 height = 200
# renderImage 0.001902
# width = 320 height = 200
# renderImage 0.001844
# width = 320 height = 200
# renderImage 0.001763
# width = 320 height = 200
# renderImage 0.001906
# width = 320 height = 200
# renderImage 0.001735
# width = 320 height = 200
# renderImage 0.001734
# width = 320 height = 200
# renderImage 0.001700
# width = 320 height = 200
# renderImage 0.001755
# width = 320 height = 200
# renderImage 0.001760
# width = 320 height = 200
# renderImage 0.001786
# width = 320 height = 200
# renderImage 0.001851
# width = 320 height = 200
# renderImage 0.001718
# width = 320 height = 200
# renderImage 0.001702
# width = 320 height = 200
# renderImage 0.001952
# width = 320 height = 200
# renderImage 0.001708
# width = 320 height = 200
# renderImage 0.001698
# width = 320 height = 200
# renderImage 0.001776
# width = 320 height = 200
# renderImage 0.001711
# width = 320 height = 200
# renderImage 0.001704
# width = 320 height = 200
# renderImage 0.001715
# width = 320 height = 200
# renderImage 0.001858
# width = 320 height = 200
# renderImage 0.001716
# width = 320 height = 200
# renderImage 0.001741
# width = 320 height = 200
# renderImage 0.001788
# width = 320 height = 200
# renderImage 0.001740
# width = 320 height = 200
# renderImage 0.001907
# width = 320 height = 200
# renderImage 0.001724
# width = 320 height = 200
# renderImage 0.001835
# width = 320 height = 200
# renderImage 0.001821
# width = 320 height = 200
# renderImage 0.001800
# width = 320 height = 200
# renderImage 0.001815
# width = 320 height = 200
# renderImage 0.001968
# width = 320 height = 200
# renderImage 0.001987
# width = 320 height = 200
# renderImage 0.001758
# width = 320 height = 200
# renderImage 0.001744
# width = 320 height = 200
# renderImage 0.001705
# width = 320 height = 200
# renderImage 0.001780
# width = 320 height = 200
# renderImage 0.001945
# width = 320 height = 200
# renderImage 0.001709
# width = 320 height = 200
# renderImage 0.001733
# width = 320 height = 200
# renderImage 0.001725
# width = 320 height = 200
# renderImage 0.001708
# width = 320 height = 200
# renderImage 0.001763
# width = 320 height = 200
# renderImage 0.001736
# width = 320 height = 200
# renderImage 0.001729
# width = 320 height = 200
# renderImage 0.001721
# width = 320 height = 200
# renderImage 0.001848
# width = 320 height = 200
# renderImage 0.001761
# width = 320 height = 200
# renderImage 0.001932
# width = 320 height = 200
# renderImage 0.001716
# width = 320 height = 200
# renderImage 0.001956
# width = 320 height = 200
# renderImage 0.001821
# width = 320 height = 200
# renderImage 0.001709
# width = 320 height = 200
# renderImage 0.001802
# width = 320 height = 200
# renderImage 0.001743
# width = 320 height = 200
# renderImage 0.001716
# width = 320 height = 200
# renderImage 0.001806
# width = 320 height = 200
# renderImage 0.001785
# width = 320 height = 200
# renderImage 0.001832
# width = 320 height = 200
# renderImage 0.001883
# width = 320 height = 200
# renderImage 0.001739
# width = 320 height = 200
# renderImage 0.001820
# width = 320 height = 200
# renderImage 0.001718
# width = 320 height = 200
# renderImage 0.001713
# width = 320 height = 200
# renderImage 0.001751
# width = 320 height = 200
# renderImage 0.001714
# width = 320 height = 200
# renderImage 0.001784
# width = 320 height = 200
# renderImage 0.001923
# width = 320 height = 200
# renderImage 0.001725
# width = 320 height = 200
# renderImage 0.001800
# width = 320 height = 200
# renderImage 0.001925
# width = 320 height = 200
# renderImage 0.001704
# width = 320 height = 200
# renderImage 0.001831
# width = 320 height = 200
# renderImage 0.001797
# width = 320 height = 200
# renderImage 0.001777
# width = 320 height = 200
# renderImage 0.001726
# width = 320 height = 200
# renderImage 0.001739
# width = 320 height = 200
# renderImage 0.001709
# width = 320 height = 200
# renderImage 0.001781
# width = 320 height = 200
# renderImage 0.001720
# width = 320 height = 200
# renderImage 0.001714
# width = 320 height = 200
# renderImage 0.001718
# width = 320 height = 200
# renderImage 0.001760
# width = 320 height = 200
# renderImage 0.001710
# width = 320 height = 200
# renderImage 0.001723
# width = 320 height = 200
# renderImage 0.001790
# width = 320 height = 200
# renderImage 0.001862
# width = 320 height = 200
# renderImage 0.001723
# width = 320 height = 200
# renderImage 0.001924
# width = 320 height = 200
# renderImage 0.001812
# width = 320 height = 200
# renderImage 0.001723
# width = 320 height = 200
# renderImage 0.001775
# width = 320 height = 200
# renderImage 0.001752
# width = 320 height = 200
# renderImage 0.001705
# width = 320 height = 200
# renderImage 0.002030
# width = 320 height = 200
# renderImage 0.001704
# width = 320 height = 200
# renderImage 0.001836
# width = 320 height = 200
# renderImage 0.001765
# width = 320 height = 200
# renderImage 0.001723
# width = 320 height = 200
# renderImage 0.001708
# width = 320 height = 200
# renderImage 0.001738
# width = 320 height = 200
# renderImage 0.001890
# width = 320 height = 200
# renderImage 0.001716
# width = 320 height = 200
# renderImage 0.001945
# width = 320 height = 200
# renderImage 0.001726
# width = 320 height = 200
# renderImage 0.001707
# width = 320 height = 200
# renderImage 0.001864
# width = 320 height = 200
# renderImage 0.001804
# width = 320 height = 200
# renderImage 0.001797
# width = 320 height = 200
# renderImage 0.001952
# width = 320 height = 200
# renderImage 0.001814
# width = 320 height = 200
# renderImage 0.001930
# width = 320 height = 200
# renderImage 0.001750
# width = 320 height = 200
# renderImage 0.001711
# width = 320 height = 200
# renderImage 0.001780
# width = 320 height = 200
# renderImage 0.001743
# width = 320 height = 200
# renderImage 0.001793
# width = 320 height = 200
# renderImage 0.001788
# width = 320 height = 200
# renderImage 0.001911
# width = 320 height = 200
# renderImage 0.001750
# width = 320 height = 200
# renderImage 0.001900
# width = 320 height = 200
# renderImage 0.001729
# width = 320 height = 200
# renderImage 0.001966
# width = 320 height = 200
# renderImage 0.001865
# width = 320 height = 200
# renderImage 0.001728
# width = 320 height = 200
# renderImage 0.002047
# width = 320 height = 200
# renderImage 0.001989
# width = 320 height = 200
# renderImage 0.001845
# width = 320 height = 200
# renderImage 0.001768
# width = 320 height = 200
# renderImage 0.001991
# width = 320 height = 200
# renderImage 0.001709
# width = 320 height = 200
# renderImage 0.001931
# width = 320 height = 200
# renderImage 0.001816
# width = 320 height = 200
# renderImage 0.001737
# width = 320 height = 200
# renderImage 0.001963
# width = 320 height = 200
# renderImage 0.001826
# width = 320 height = 200
# renderImage 0.001707
# width = 320 height = 200
# renderImage 0.001848
# width = 320 height = 200
# renderImage 0.001723
# width = 320 height = 200
# renderImage 0.001751
# width = 320 height = 200
# renderImage 0.001773
# width = 320 height = 200
# renderImage 0.001705
# width = 320 height = 200
# renderImage 0.001808
# width = 320 height = 200
# renderImage 0.001723
# width = 320 height = 200
# renderImage 0.001740
# width = 320 height = 200
# renderImage 0.001750
# width = 320 height = 200
# renderImage 0.001981
# width = 320 height = 200
# renderImage 0.002073
# width = 320 height = 200
# renderImage 0.001797
# width = 320 height = 200
# renderImage 0.001839
# width = 320 height = 200
# renderImage 0.001736
# width = 320 height = 200
# renderImage 0.001792
# width = 320 height = 200
# renderImage 0.001757
# width = 320 height = 200
# renderImage 0.001821
# width = 320 height = 200
# renderImage 0.001709
# width = 320 height = 200
# renderImage 0.001721
# width = 320 height = 200
# renderImage 0.001725
# width = 320 height = 200
# renderImage 0.001755
# width = 320 height = 200
